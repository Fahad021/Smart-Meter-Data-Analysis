# %%
import pandas as pd

df = pd.read_csv("pivoted_vltsdb_kwversion_hourly_resampled.csv")
df
# Out:
#               interval_end  00374f87-909c-6ef8-847f-a7b4694ad804  \
# 0      2015-01-01 05:00:00                                   0.0
# 1      2015-01-01 06:00:00                                   0.0
# 2      2015-01-01 07:00:00                                   0.0
# 3      2015-01-01 08:00:00                                   0.0
# 4      2015-01-01 09:00:00                                   0.0
# ...                    ...                                   ...
# 33908  2018-11-14 01:00:00                                   0.0
# 33909  2018-11-14 02:00:00                                   0.0
# 33910  2018-11-14 03:00:00                                   0.0
# 33911  2018-11-14 04:00:00                                   0.0
# 33912  2018-11-14 05:00:00                                   0.0
#
#        0101ee7c-a0ef-7b94-f62b-594142c8b0e6  \
# 0                                       0.0
# 1                                       0.0
# 2                                       0.0
# ...

# %%
df.describe()
# Out:
#        00374f87-909c-6ef8-847f-a7b4694ad804  \
# count                          33913.000000
# mean                            4712.293368
# std                             2773.546225
# min                                0.000000
# 25%                             2735.100000
# 50%                             4195.800000
# 75%                             7335.900000
# max                            10076.400000
#
#        0101ee7c-a0ef-7b94-f62b-594142c8b0e6  \
# count                               33913.0
# mean                                    0.0
# std                                     0.0
# min                                     0.0
# 25%                                     0.0
# 50%                                     0.0
# 75%                                     0.0
# max                                     0.0
#
#        012091d7-8dfd-1322-28e4-4a3c57b067c7  \
# count                          33913.000000
# mean                            5608.383107
# ...

# %%
from adtk.data import validate_series
from adtk.detector import SeasonalAD

df.index = df.interval_end
df.idex = pd.to_datetime(df.index)


seasonal_ids = ['00374f87-909c-6ef8-847f-a7b4694ad804',
 '00374f87-909c-6ef8-847f-a7b4694ad804',
 '012091d7-8dfd-1322-28e4-4a3c57b067c7',
 '012091d7-8dfd-1322-28e4-4a3c57b067c7',
 '02f4e241-53ef-7fb8-ff1d-ba17643d7645',
 '02f4e241-53ef-7fb8-ff1d-ba17643d7645',
 '02fb6917-572b-6e82-8f53-2dd1fb188a3c',
 '03dde450-8366-1cb8-1632-f6c8135b8077',
 '0644edc0-0417-d12c-b3cb-505bc2e3e258',
 '08737ad9-2384-03d2-6557-83958fc5d881',
 '08737ad9-2384-03d2-6557-83958fc5d881',
 '08ff275a-aaf6-bda6-7df1-2730c9ab29b7',
 '08ff275a-aaf6-bda6-7df1-2730c9ab29b7',
 '09473fb0-9258-71fa-827b-fabb32404ca6',
 '11a7bb84-7601-0161-9588-b9b5020518e5',
 '11ba23cb-dfd8-bf06-3ab1-7ac4ad6f1d5c',
 '1374c5d3-9816-3f20-2d93-73e81fe6892f',
 '168c044a-2cc8-92b6-fe42-806449544be4',
 '1c82b217-174d-63af-01b2-2e0d35c85cd2',
 '1d07f991-8621-bbc8-d597-39c6b125f662',
 '1d07f991-8621-bbc8-d597-39c6b125f662',
 '20091471-e961-3d8d-0cf7-b686dff662d4',
 'ee9e572d-9840-3093-811f-941b7f48e73f',
 'f2f57d71-344e-adda-6441-3b7d6620dd40',
 'f58c29d4-da39-b21a-6280-579f4b04af08',
 'f642e2d0-64fb-a3a4-82a3-1e6c9374f0ae',
 'f7cb6999-e8e4-8dc2-a609-4b1b5c0ca9c9',
 'f7cb6999-e8e4-8dc2-a609-4b1b5c0ca9c9',
 'f81d7812-364c-67ba-2379-bd4b8a6a87ba',
 'fa1e6d9b-9562-02aa-0a4a-3f08fdf1c960',
 'fa918bd3-d0f3-0e2d-08c6-875ade30fe3e',
 'fb203000-0b6e-e587-0168-25b53c60a153']


all_event = pd.DataFrame()
for ids in seasonal_ids:
    df_test = df[[ids]]
    df_test.index = pd.to_datetime(df_test.index)
    s_train = validate_series(df_test)
    seasonal_ad = SeasonalAD()
    anomalies = seasonal_ad.fit_detect(s_train)
    all_event = all_event.append(anomalies.loc[anomalies.iloc[:,0] == True])
    print(anomalies.loc[anomalies.iloc[:,0] == True])

all_event.to_csv('all_dr_event_vlts.csv')
# Out:
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """
#                      00374f87-909c-6ef8-847f-a7b4694ad804
# interval_end
# 2015-01-01 10:00:00                                  True
# 2015-01-01 11:00:00                                  True
# 2015-01-01 12:00:00                                  True
# 2015-01-01 13:00:00                                  True
# 2015-01-01 14:00:00                                  True
# ...                                                   ...
# 2018-11-13 19:00:00                                  True
# 2018-11-13 20:00:00                                  True
# 2018-11-13 21:00:00                                  True
# 2018-11-13 22:00:00                                  True
# ...

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4g}'.format
import enlopy as el
from sklearn.preprocessing import MaxAbsScaler
import pickle

from adtk.data import validate_series
from adtk.detector import SeasonalAD, QuantileAD

file_name = "hourly_sampled.pkl"
open_file = open(file_name, "rb")
loaded_list = pickle.load(open_file)
open_file.close()

hourly_site_id_seasonality = pd.read_csv('hourly_siteid_seasonality_result.csv')
hourly_site_id_seasonality = hourly_site_id_seasonality[['site_id','seasonality']]


hourly_anomalies = pd.DataFrame()

for i in range(0,len(loaded_list)):
    df1= df.loc[df['site_id']== loaded_list[i]]
    df2 = hourly_site_id_seasonality.loc[hourly_site_id_seasonality['site_id']==loaded_list[i]]
    print(loaded_list[i]+' ===>')
    df1.interval_end = pd.to_datetime(df1.interval_end)
    df1.index= df1.interval_end
    df1.sort_index()
    df1 = df1['kw']
    if int(df2.seasonality.values)> 0:
        s_train = validate_series(df1)
        seasonal_ad = SeasonalAD(c=1.0, side="both")
        anomalies = seasonal_ad.fit_detect(s_train)
        hourly_anomalies = hourly_anomalies.append(anomalies.loc[anomalies.iloc[:,0] == True])
    else:
        s_train = validate_series(df1)
        quantile_ad = QuantileAD(high=0.99, low=0.01)
        anomalies = quantile_ad.fit_detect(s_train)
        hourly_anomalies = hourly_anomalies.append(anomalies.loc[anomalies.iloc[:,0] == True])
