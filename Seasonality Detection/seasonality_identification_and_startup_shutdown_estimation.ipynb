# %%
import pandas as pd

columns = ['kwh','interval_end','interval_width','site_id']
df = pd.read_csv("vltsdb.csv", names= columns)
df['kw'] = df['kwh']*(3600./df['interval_width'])
df
# Out:
#            kwh         interval_end  interval_width  \
# 0         43.2  2017-07-16 02:15:00             900
# 1        42.12  2017-07-16 02:30:00             900
# 2        41.58  2017-07-16 02:45:00             900
# 3        41.22  2017-07-16 03:00:00             900
# 4         42.3  2017-07-16 03:15:00             900
# ...        ...                  ...             ...
# 16648407 43.74  2017-07-16 01:00:00             900
# 16648408 42.48  2017-07-16 01:15:00             900
# 16648409  43.2  2017-07-16 01:30:00             900
# 16648410 41.76  2017-07-16 01:45:00             900
# 16648411 41.76  2017-07-16 02:00:00             900
#
#                                        site_id    kw
# 0         67558069-06d2-2b8a-e0a8-18cc5444c287 172.8
# 1         67558069-06d2-2b8a-e0a8-18cc5444c287 168.5
# 2         67558069-06d2-2b8a-e0a8-18cc5444c287 166.3
# 3         67558069-06d2-2b8a-e0a8-18cc5444c287 164.9
# 4         67558069-06d2-2b8a-e0a8-18cc5444c287 169.2
# ...                                        ...   ...
# 16648407  67558069-06d2-2b8a-e0a8-18cc5444c287   175
# 16648408  67558069-06d2-2b8a-e0a8-18cc5444c287 169.9
# 16648409  67558069-06d2-2b8a-e0a8-18cc5444c287 172.8
# 16648410  67558069-06d2-2b8a-e0a8-18cc5444c287   167
# 16648411  67558069-06d2-2b8a-e0a8-18cc5444c287   167
#
# [16648412 rows x 5 columns]

# %%
import numpy as np
from pandas.tseries.frequencies import to_offset
from datetime import timedelta
from scipy.fftpack import fft, fftfreq
from statsmodels.tsa.stattools import acf
import pickle

file_name = "fifteen_minute_sampled.pkl"
open_file = open(file_name, "rb")
loaded_list = pickle.load(open_file)
open_file.close()

seasonality_check_subhourly_sampled = []

freq_data = '15min'

df_time_delta = pd.to_timedelta(to_offset(freq_data))

# Daily and Weekly seasons expected values from DF
time_lags_expected = [int(timedelta(days=1) / df_time_delta), int(timedelta(days=7) / df_time_delta)]

for id in loaded_list:
    # get top 3 seasons
    no_of_seasons=3
    
    df1= df.loc[df['site_id']== id]
    print(id+' ===>')
    df1.interval_end = pd.to_datetime(df1.interval_end)
    df1.index= df1.interval_end
    df1.sort_index()
    df1 = df1['kw']
    
    series = np.asarray(df1)
    # Compute FFT
    series_fft = fft(series)

    # Compute the power
    power = np.abs(series_fft)

    # Get the corresponding frequencies
    sample_freq = fftfreq(series_fft.size)

    # Find the peak frequency: we only need the positive frequencies
    pos_mask = np.where(sample_freq > 0)
    freqs = sample_freq[pos_mask]
    powers = power[pos_mask]

    # find top frequencies and corresponding time periods for seasonal pattern
    top_powers = np.argpartition(powers, -no_of_seasons)[-no_of_seasons:]

    time_periods_from_fft = 1 / freqs[top_powers]
    time_periods = time_periods_from_fft.astype(int)
    count = 0

    # One of the seasonality returned from FFT should be within range of Expected time period
    for time_lag in time_lags_expected:
        nearest_time_lag = time_periods.flat[np.abs(time_periods - time_lag).argmin()]

        #Using 5% for range comaprison
        if nearest_time_lag in range(
                time_lag - int(0.05 * time_lag),
                time_lag + int(0.05 * time_lag)):

            # Check ACF value with lags identified from FFT.
            acf_score = acf(series, nlags=nearest_time_lag)[-1]

            # Check ACF is significant or not.
            if acf_score >= 2 / np.sqrt(len(series)):
                # ACF is significant and FFT identifies seasonality
                count = count + 1
                print(str(count)+' for '+str(time_lag)+' seasonality,the site_id '+ id+' '+'is seasonal')
        else:
            print(str(count)+' for'+' '+str(time_lag)+ ' seasonality,'+'the site_id '+ id+'  Seasonality could not be identified')
    data = pd.DataFrame({"site_id":[id],"seasonality":[count]})
    seasonality_check_subhourly_sampled. append(data)

seasonality_check_subhourly_sampled  = pd.concat(seasonality_check_subhourly_sampled)
seasonality_check_subhourly_sampled
# Out:
# 67558069-06d2-2b8a-e0a8-18cc5444c287 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:572: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   FutureWarning
# 1 for 96 seasonality,the site_id 67558069-06d2-2b8a-e0a8-18cc5444c287 is seasonal
# 2 for 672 seasonality,the site_id 67558069-06d2-2b8a-e0a8-18cc5444c287 is seasonal
# de387a8e-521d-bb89-84a1-650ed26e5437 ===>
# 1 for 96 seasonality,the site_id de387a8e-521d-bb89-84a1-650ed26e5437 is seasonal
# 1 for 672 seasonality,the site_id de387a8e-521d-bb89-84a1-650ed26e5437  Seasonality could not be identified
# 25b9093b-4a6a-8c35-1545-e25cee8b7f3a ===>
# 1 for 96 seasonality,the site_id 25b9093b-4a6a-8c35-1545-e25cee8b7f3a is seasonal
# 1 for 672 seasonality,the site_id 25b9093b-4a6a-8c35-1545-e25cee8b7f3a  Seasonality could not be identified
# d1668f39-1f93-e186-9d6c-acb8ba6567e4 ===>
# 1 for 96 seasonality,the site_id d1668f39-1f93-e186-9d6c-acb8ba6567e4 is seasonal
# 1 for 672 seasonality,the site_id d1668f39-1f93-e186-9d6c-acb8ba6567e4  Seasonality could not be identified
# d243bd72-6f64-b597-3db6-72159081dcf4 ===>
# 1 for 96 seasonality,the site_id d243bd72-6f64-b597-3db6-72159081dcf4 is seasonal
# 1 for 672 seasonality,the site_id d243bd72-6f64-b597-3db6-72159081dcf4  Seasonality could not be identified
# 4721a1d8-197d-36f8-0a79-a2f3819ead5d ===>
# 1 for 96 seasonality,the site_id 4721a1d8-197d-36f8-0a79-a2f3819ead5d is seasonal
# 2 for 672 seasonality,the site_id 4721a1d8-197d-36f8-0a79-a2f3819ead5d is seasonal
# 46ad5df5-ae69-be7e-cc46-9c02132e204a ===>
# 1 for 96 seasonality,the site_id 46ad5df5-ae69-be7e-cc46-9c02132e204a is seasonal
# 2 for 672 seasonality,the site_id 46ad5df5-ae69-be7e-cc46-9c02132e204a is seasonal
# 50877f54-bd2c-9048-b1bc-8fdc3a00d21e ===>
# 1 for 96 seasonality,the site_id 50877f54-bd2c-9048-b1bc-8fdc3a00d21e is seasonal
# 2 for 672 seasonality,the site_id 50877f54-bd2c-9048-b1bc-8fdc3a00d21e is seasonal
# f1fc624e-00ad-2e4a-4e6b-0a3391a90fdf ===>
# 1 for 96 seasonality,the site_id f1fc624e-00ad-2e4a-4e6b-0a3391a90fdf is seasonal
# 2 for 672 seasonality,the site_id f1fc624e-00ad-2e4a-4e6b-0a3391a90fdf is seasonal
# 989da191-fdc5-2eee-2cc9-ad35a0bbb863 ===>
# 1 for 96 seasonality,the site_id 989da191-fdc5-2eee-2cc9-ad35a0bbb863 is seasonal
# 2 for 672 seasonality,the site_id 989da191-fdc5-2eee-2cc9-ad35a0bbb863 is seasonal
# 7dbed726-1d39-44ff-ac26-02374efd3b99 ===>
# 1 for 96 seasonality,the site_id 7dbed726-1d39-44ff-ac26-02374efd3b99 is seasonal
# 2 for 672 seasonality,the site_id 7dbed726-1d39-44ff-ac26-02374efd3b99 is seasonal
# f7cb6999-e8e4-8dc2-a609-4b1b5c0ca9c9 ===>
# 1 for 96 seasonality,the site_id f7cb6999-e8e4-8dc2-a609-4b1b5c0ca9c9 is seasonal
# 2 for 672 seasonality,the site_id f7cb6999-e8e4-8dc2-a609-4b1b5c0ca9c9 is seasonal
# 291a7e63-beb1-09b7-601c-93c326be0607 ===>
# 1 for 96 seasonality,the site_id 291a7e63-beb1-09b7-601c-93c326be0607 is seasonal
# 2 for 672 seasonality,the site_id 291a7e63-beb1-09b7-601c-93c326be0607 is seasonal
# 168c044a-2cc8-92b6-fe42-806449544be4 ===>
# 1 for 96 seasonality,the site_id 168c044a-2cc8-92b6-fe42-806449544be4 is seasonal
# 2 for 672 seasonality,the site_id 168c044a-2cc8-92b6-fe42-806449544be4 is seasonal
# ee9e572d-9840-3093-811f-941b7f48e73f ===>
# 0 for 96 seasonality,the site_id ee9e572d-9840-3093-811f-941b7f48e73f  Seasonality could not be identified
# 1 for 672 seasonality,the site_id ee9e572d-9840-3093-811f-941b7f48e73f is seasonal
# e3837638-f454-5de6-0a0f-51d5ccc43f65 ===>
# 0 for 96 seasonality,the site_id e3837638-f454-5de6-0a0f-51d5ccc43f65  Seasonality could not be identified
# 0 for 672 seasonality,the site_id e3837638-f454-5de6-0a0f-51d5ccc43f65  Seasonality could not be identified
# adeeddca-5043-9a55-278a-db8b50518baa ===>
# 0 for 96 seasonality,the site_id adeeddca-5043-9a55-278a-db8b50518baa  Seasonality could not be identified
# 1 for 672 seasonality,the site_id adeeddca-5043-9a55-278a-db8b50518baa is seasonal
# 3f461171-89c5-fd7f-8e4a-1483094e74c2 ===>
# 0 for 96 seasonality,the site_id 3f461171-89c5-fd7f-8e4a-1483094e74c2  Seasonality could not be identified
# 0 for 672 seasonality,the site_id 3f461171-89c5-fd7f-8e4a-1483094e74c2  Seasonality could not be identified
# 1374c5d3-9816-3f20-2d93-73e81fe6892f ===>
# 0 for 96 seasonality,the site_id 1374c5d3-9816-3f20-2d93-73e81fe6892f  Seasonality could not be identified
# 0 for 672 seasonality,the site_id 1374c5d3-9816-3f20-2d93-73e81fe6892f  Seasonality could not be identified
# 3feaeec7-c201-c614-d067-1c6db38f2255 ===>
# 0 for 96 seasonality,the site_id 3feaeec7-c201-c614-d067-1c6db38f2255  Seasonality could not be identified
# 0 for 672 seasonality,the site_id 3feaeec7-c201-c614-d067-1c6db38f2255  Seasonality could not be identified
# 49d4b6e2-1c91-8aea-8f1d-49367fb47ada ===>
# 1 for 96 seasonality,the site_id 49d4b6e2-1c91-8aea-8f1d-49367fb47ada is seasonal
# 1 for 672 seasonality,the site_id 49d4b6e2-1c91-8aea-8f1d-49367fb47ada  Seasonality could not be identified
# cb846659-8aa0-3233-6b11-6745474c94c3 ===>
# 0 for 96 seasonality,the site_id cb846659-8aa0-3233-6b11-6745474c94c3  Seasonality could not be identified
# 0 for 672 seasonality,the site_id cb846659-8aa0-3233-6b11-6745474c94c3  Seasonality could not be identified
# e7d819a2-4382-e7d1-a267-069c96a54333 ===>
# 0 for 96 seasonality,the site_id e7d819a2-4382-e7d1-a267-069c96a54333  Seasonality could not be identified
# 0 for 672 seasonality,the site_id e7d819a2-4382-e7d1-a267-069c96a54333  Seasonality could not be identified
# 66e9c85d-6b5f-d012-4b56-f69218073f86 ===>
# 0 for 96 seasonality,the site_id 66e9c85d-6b5f-d012-4b56-f69218073f86  Seasonality could not be identified
# 0 for 672 seasonality,the site_id 66e9c85d-6b5f-d012-4b56-f69218073f86  Seasonality could not be identified
# 871f9fba-e8c7-cdcd-1ac4-863509f1be51 ===>
# 0 for 96 seasonality,the site_id 871f9fba-e8c7-cdcd-1ac4-863509f1be51  Seasonality could not be identified
# 0 for 672 seasonality,the site_id 871f9fba-e8c7-cdcd-1ac4-863509f1be51  Seasonality could not be identified
# 1692d346-175f-4b14-bcd4-1c3489a07e7b ===>
# 1 for 96 seasonality,the site_id 1692d346-175f-4b14-bcd4-1c3489a07e7b is seasonal
# 1 for 672 seasonality,the site_id 1692d346-175f-4b14-bcd4-1c3489a07e7b  Seasonality could not be identified
# e386ac24-700c-eff1-1e89-2fa4a3757fa4 ===>
# 1 for 96 seasonality,the site_id e386ac24-700c-eff1-1e89-2fa4a3757fa4 is seasonal
# 1 for 672 seasonality,the site_id e386ac24-700c-eff1-1e89-2fa4a3757fa4  Seasonality could not be identified
# 62194036-a4ec-91df-6a8f-9584b72c4b28 ===>
# 1 for 96 seasonality,the site_id 62194036-a4ec-91df-6a8f-9584b72c4b28 is seasonal
# 1 for 672 seasonality,the site_id 62194036-a4ec-91df-6a8f-9584b72c4b28  Seasonality could not be identified
# e3b32a97-7ca4-1af7-a7be-f80859145b2c ===>
# 1 for 96 seasonality,the site_id e3b32a97-7ca4-1af7-a7be-f80859145b2c is seasonal
# 1 for 672 seasonality,the site_id e3b32a97-7ca4-1af7-a7be-f80859145b2c  Seasonality could not be identified
# 77263deb-497e-eb40-93d8-08e12404ae0f ===>
# 1 for 96 seasonality,the site_id 77263deb-497e-eb40-93d8-08e12404ae0f is seasonal
# 1 for 672 seasonality,the site_id 77263deb-497e-eb40-93d8-08e12404ae0f  Seasonality could not be identified
# eee5ec4a-dfca-a932-e1a3-0b02a323f4b5 ===>
# 1 for 96 seasonality,the site_id eee5ec4a-dfca-a932-e1a3-0b02a323f4b5 is seasonal
# 1 for 672 seasonality,the site_id eee5ec4a-dfca-a932-e1a3-0b02a323f4b5  Seasonality could not be identified
# 31aaa2cb-057c-d0a8-6788-bb6ecb3ada56 ===>
# 1 for 96 seasonality,the site_id 31aaa2cb-057c-d0a8-6788-bb6ecb3ada56 is seasonal
# 1 for 672 seasonality,the site_id 31aaa2cb-057c-d0a8-6788-bb6ecb3ada56  Seasonality could not be identified
# 5c4475bf-d7df-3514-9ff1-07f0e9514500 ===>
# 1 for 96 seasonality,the site_id 5c4475bf-d7df-3514-9ff1-07f0e9514500 is seasonal
# 1 for 672 seasonality,the site_id 5c4475bf-d7df-3514-9ff1-07f0e9514500  Seasonality could not be identified
# 269d0b8a-8350-36b4-67c3-3e29d6041b5c ===>
# 1 for 96 seasonality,the site_id 269d0b8a-8350-36b4-67c3-3e29d6041b5c is seasonal
# 1 for 672 seasonality,the site_id 269d0b8a-8350-36b4-67c3-3e29d6041b5c  Seasonality could not be identified
# 0414cdc3-fc98-163e-3e99-6c42cb74181f ===>
# 1 for 96 seasonality,the site_id 0414cdc3-fc98-163e-3e99-6c42cb74181f is seasonal
# 1 for 672 seasonality,the site_id 0414cdc3-fc98-163e-3e99-6c42cb74181f  Seasonality could not be identified
# 2b6760b7-8ae4-fb53-be51-713996a844f0 ===>
# 1 for 96 seasonality,the site_id 2b6760b7-8ae4-fb53-be51-713996a844f0 is seasonal
# 1 for 672 seasonality,the site_id 2b6760b7-8ae4-fb53-be51-713996a844f0  Seasonality could not be identified
# de2c074a-fb17-463d-8aa0-174087899129 ===>
# 1 for 96 seasonality,the site_id de2c074a-fb17-463d-8aa0-174087899129 is seasonal
# 1 for 672 seasonality,the site_id de2c074a-fb17-463d-8aa0-174087899129  Seasonality could not be identified
# 0e5f3c13-b90f-b044-dfb9-b5192754f78a ===>
# 1 for 96 seasonality,the site_id 0e5f3c13-b90f-b044-dfb9-b5192754f78a is seasonal
# 1 for 672 seasonality,the site_id 0e5f3c13-b90f-b044-dfb9-b5192754f78a  Seasonality could not be identified
# 1a70c79d-b5fd-0724-0442-327519687fe6 ===>
# 1 for 96 seasonality,the site_id 1a70c79d-b5fd-0724-0442-327519687fe6 is seasonal
# 1 for 672 seasonality,the site_id 1a70c79d-b5fd-0724-0442-327519687fe6  Seasonality could not be identified
# 8ab0b38f-bad7-2fae-1ba6-24e2eb146f82 ===>
# 1 for 96 seasonality,the site_id 8ab0b38f-bad7-2fae-1ba6-24e2eb146f82 is seasonal
# 1 for 672 seasonality,the site_id 8ab0b38f-bad7-2fae-1ba6-24e2eb146f82  Seasonality could not be identified
# 8fcfa75c-e407-187d-c37c-784cac8e6c7b ===>
# 1 for 96 seasonality,the site_id 8fcfa75c-e407-187d-c37c-784cac8e6c7b is seasonal
# 1 for 672 seasonality,the site_id 8fcfa75c-e407-187d-c37c-784cac8e6c7b  Seasonality could not be identified
# 93833ebe-84d8-577e-7fd6-84646a06e588 ===>
# 1 for 96 seasonality,the site_id 93833ebe-84d8-577e-7fd6-84646a06e588 is seasonal
# 1 for 672 seasonality,the site_id 93833ebe-84d8-577e-7fd6-84646a06e588  Seasonality could not be identified
# 11a7bb84-7601-0161-9588-b9b5020518e5 ===>
# 1 for 96 seasonality,the site_id 11a7bb84-7601-0161-9588-b9b5020518e5 is seasonal
# 1 for 672 seasonality,the site_id 11a7bb84-7601-0161-9588-b9b5020518e5  Seasonality could not be identified
# cc250a40-4b23-6077-95f5-e207d3ddcf42 ===>
# 1 for 96 seasonality,the site_id cc250a40-4b23-6077-95f5-e207d3ddcf42 is seasonal
# 1 for 672 seasonality,the site_id cc250a40-4b23-6077-95f5-e207d3ddcf42  Seasonality could not be identified
# 7e1cc7bc-6e8b-6546-2cf1-f8027dc18fe5 ===>
# 1 for 96 seasonality,the site_id 7e1cc7bc-6e8b-6546-2cf1-f8027dc18fe5 is seasonal
# 1 for 672 seasonality,the site_id 7e1cc7bc-6e8b-6546-2cf1-f8027dc18fe5  Seasonality could not be identified
# 0bebeb97-fddb-c886-3899-5d221e89b86a ===>
# 1 for 96 seasonality,the site_id 0bebeb97-fddb-c886-3899-5d221e89b86a is seasonal
# 1 for 672 seasonality,the site_id 0bebeb97-fddb-c886-3899-5d221e89b86a  Seasonality could not be identified
# c9564661-aa09-5ae1-1b4f-eaac485a824e ===>
# 1 for 96 seasonality,the site_id c9564661-aa09-5ae1-1b4f-eaac485a824e is seasonal
# 1 for 672 seasonality,the site_id c9564661-aa09-5ae1-1b4f-eaac485a824e  Seasonality could not be identified
# c459150f-6be4-34ec-e9fd-74fb30a5fcf1 ===>
# 1 for 96 seasonality,the site_id c459150f-6be4-34ec-e9fd-74fb30a5fcf1 is seasonal
# 1 for 672 seasonality,the site_id c459150f-6be4-34ec-e9fd-74fb30a5fcf1  Seasonality could not be identified
# d416c8b2-2830-af5a-6862-a79df1d9a392 ===>
# 1 for 96 seasonality,the site_id d416c8b2-2830-af5a-6862-a79df1d9a392 is seasonal
# 1 for 672 seasonality,the site_id d416c8b2-2830-af5a-6862-a79df1d9a392  Seasonality could not be identified
# ce975f7d-c364-6d48-0a2c-ba17b480fe8c ===>
# 1 for 96 seasonality,the site_id ce975f7d-c364-6d48-0a2c-ba17b480fe8c is seasonal
# 1 for 672 seasonality,the site_id ce975f7d-c364-6d48-0a2c-ba17b480fe8c  Seasonality could not be identified
# 61ff3699-aad4-35d3-4ecb-b8195e8b08cd ===>
# 1 for 96 seasonality,the site_id 61ff3699-aad4-35d3-4ecb-b8195e8b08cd is seasonal
# 1 for 672 seasonality,the site_id 61ff3699-aad4-35d3-4ecb-b8195e8b08cd  Seasonality could not be identified
# d66979ba-4d38-6ebc-865b-e9e28936f289 ===>
# 1 for 96 seasonality,the site_id d66979ba-4d38-6ebc-865b-e9e28936f289 is seasonal
# 1 for 672 seasonality,the site_id d66979ba-4d38-6ebc-865b-e9e28936f289  Seasonality could not be identified
# 9fe91411-9092-2ce4-aabc-dd3c6868d50a ===>
# 0 for 96 seasonality,the site_id 9fe91411-9092-2ce4-aabc-dd3c6868d50a  Seasonality could not be identified
# 0 for 672 seasonality,the site_id 9fe91411-9092-2ce4-aabc-dd3c6868d50a  Seasonality could not be identified
# 22f70f53-453d-9f22-24ca-b62a313ca6aa ===>
# 1 for 96 seasonality,the site_id 22f70f53-453d-9f22-24ca-b62a313ca6aa is seasonal
# 1 for 672 seasonality,the site_id 22f70f53-453d-9f22-24ca-b62a313ca6aa  Seasonality could not be identified
# d7a24f2e-cd47-d543-657c-fce56ef00c31 ===>
# 1 for 96 seasonality,the site_id d7a24f2e-cd47-d543-657c-fce56ef00c31 is seasonal
# 1 for 672 seasonality,the site_id d7a24f2e-cd47-d543-657c-fce56ef00c31  Seasonality could not be identified
# 845d744a-be52-529f-e4e7-52ea1868719a ===>
# 1 for 96 seasonality,the site_id 845d744a-be52-529f-e4e7-52ea1868719a is seasonal
# 1 for 672 seasonality,the site_id 845d744a-be52-529f-e4e7-52ea1868719a  Seasonality could not be identified
# c7104b57-7c8a-e5b5-cf60-f8ccbc15a7f2 ===>
# 1 for 96 seasonality,the site_id c7104b57-7c8a-e5b5-cf60-f8ccbc15a7f2 is seasonal
# 1 for 672 seasonality,the site_id c7104b57-7c8a-e5b5-cf60-f8ccbc15a7f2  Seasonality could not be identified
# 2acbd281-726f-e240-ebae-080d2a672929 ===>
# 1 for 96 seasonality,the site_id 2acbd281-726f-e240-ebae-080d2a672929 is seasonal
# 1 for 672 seasonality,the site_id 2acbd281-726f-e240-ebae-080d2a672929  Seasonality could not be identified
# f4cfaa89-53bb-3d30-c887-0b022b313e7a ===>
# 0 for 96 seasonality,the site_id f4cfaa89-53bb-3d30-c887-0b022b313e7a  Seasonality could not be identified
# 0 for 672 seasonality,the site_id f4cfaa89-53bb-3d30-c887-0b022b313e7a  Seasonality could not be identified
# f771d6db-d64e-2ff2-f50d-47be0ad31b9c ===>
# 0 for 96 seasonality,the site_id f771d6db-d64e-2ff2-f50d-47be0ad31b9c  Seasonality could not be identified
# 0 for 672 seasonality,the site_id f771d6db-d64e-2ff2-f50d-47be0ad31b9c  Seasonality could not be identified
# a810f563-73b5-e8e0-9a71-de09c82c6079 ===>
# 1 for 96 seasonality,the site_id a810f563-73b5-e8e0-9a71-de09c82c6079 is seasonal
# 1 for 672 seasonality,the site_id a810f563-73b5-e8e0-9a71-de09c82c6079  Seasonality could not be identified
# f6d9da6a-66e4-c805-43dc-c6b8b77a22c6 ===>
# 0 for 96 seasonality,the site_id f6d9da6a-66e4-c805-43dc-c6b8b77a22c6  Seasonality could not be identified
# 0 for 672 seasonality,the site_id f6d9da6a-66e4-c805-43dc-c6b8b77a22c6  Seasonality could not be identified
# a4182267-11d3-0c70-03b2-8df1412e250c ===>
# 1 for 96 seasonality,the site_id a4182267-11d3-0c70-03b2-8df1412e250c is seasonal
# 1 for 672 seasonality,the site_id a4182267-11d3-0c70-03b2-8df1412e250c  Seasonality could not be identified
# 470f0ef8-244f-e174-0201-3d9c0783d463 ===>
# 0 for 96 seasonality,the site_id 470f0ef8-244f-e174-0201-3d9c0783d463  Seasonality could not be identified
# 0 for 672 seasonality,the site_id 470f0ef8-244f-e174-0201-3d9c0783d463  Seasonality could not be identified
# fbba4fe0-ad9b-ec46-575c-c22ff0a20186 ===>
# 1 for 96 seasonality,the site_id fbba4fe0-ad9b-ec46-575c-c22ff0a20186 is seasonal
# 1 for 672 seasonality,the site_id fbba4fe0-ad9b-ec46-575c-c22ff0a20186  Seasonality could not be identified
# 8a44ff16-3c57-8800-d9ae-b579ae7c74fd ===>
# 1 for 96 seasonality,the site_id 8a44ff16-3c57-8800-d9ae-b579ae7c74fd is seasonal
# 1 for 672 seasonality,the site_id 8a44ff16-3c57-8800-d9ae-b579ae7c74fd  Seasonality could not be identified
# cd9f2c33-740b-4702-9b74-5c8acb54f9af ===>
# 0 for 96 seasonality,the site_id cd9f2c33-740b-4702-9b74-5c8acb54f9af  Seasonality could not be identified
# 0 for 672 seasonality,the site_id cd9f2c33-740b-4702-9b74-5c8acb54f9af  Seasonality could not be identified
# feba96eb-7c85-a150-dfa6-ed45a7fda60b ===>
# 0 for 96 seasonality,the site_id feba96eb-7c85-a150-dfa6-ed45a7fda60b  Seasonality could not be identified
# 0 for 672 seasonality,the site_id feba96eb-7c85-a150-dfa6-ed45a7fda60b  Seasonality could not be identified
# 412ee760-0692-d284-ef00-a91dc3516e81 ===>
# 1 for 96 seasonality,the site_id 412ee760-0692-d284-ef00-a91dc3516e81 is seasonal
# 1 for 672 seasonality,the site_id 412ee760-0692-d284-ef00-a91dc3516e81  Seasonality could not be identified
# e746baf2-13cc-6400-05b7-ab05d8937b9a ===>
# 1 for 96 seasonality,the site_id e746baf2-13cc-6400-05b7-ab05d8937b9a is seasonal
# 1 for 672 seasonality,the site_id e746baf2-13cc-6400-05b7-ab05d8937b9a  Seasonality could not be identified
# c473d463-8c9c-afc1-a507-f3e38d9d6320 ===>
# 1 for 96 seasonality,the site_id c473d463-8c9c-afc1-a507-f3e38d9d6320 is seasonal
# 1 for 672 seasonality,the site_id c473d463-8c9c-afc1-a507-f3e38d9d6320  Seasonality could not be identified
# 7e7d4cee-9b6d-698b-2ef8-324090f22a95 ===>
# 1 for 96 seasonality,the site_id 7e7d4cee-9b6d-698b-2ef8-324090f22a95 is seasonal
# 1 for 672 seasonality,the site_id 7e7d4cee-9b6d-698b-2ef8-324090f22a95  Seasonality could not be identified
# 14c78171-fcca-bf8a-9d0b-2a75bce2b5e9 ===>
# 1 for 96 seasonality,the site_id 14c78171-fcca-bf8a-9d0b-2a75bce2b5e9 is seasonal
# 1 for 672 seasonality,the site_id 14c78171-fcca-bf8a-9d0b-2a75bce2b5e9  Seasonality could not be identified
# e29e903f-f76f-1057-4fc7-4c2d91c09067 ===>
# 1 for 96 seasonality,the site_id e29e903f-f76f-1057-4fc7-4c2d91c09067 is seasonal
# 1 for 672 seasonality,the site_id e29e903f-f76f-1057-4fc7-4c2d91c09067  Seasonality could not be identified
# a2c4873d-ee68-7f14-b485-10f4c400ba59 ===>
# 1 for 96 seasonality,the site_id a2c4873d-ee68-7f14-b485-10f4c400ba59 is seasonal
# 1 for 672 seasonality,the site_id a2c4873d-ee68-7f14-b485-10f4c400ba59  Seasonality could not be identified
# 7b59d921-c882-0ca0-7f89-fb8d60362225 ===>
# 1 for 96 seasonality,the site_id 7b59d921-c882-0ca0-7f89-fb8d60362225 is seasonal
# 1 for 672 seasonality,the site_id 7b59d921-c882-0ca0-7f89-fb8d60362225  Seasonality could not be identified
# 7e942ab7-170a-97da-c38f-c052a53b1b90 ===>
# 1 for 96 seasonality,the site_id 7e942ab7-170a-97da-c38f-c052a53b1b90 is seasonal
# 1 for 672 seasonality,the site_id 7e942ab7-170a-97da-c38f-c052a53b1b90  Seasonality could not be identified
# b3bf475a-41f8-65a5-08cc-ed0f38aeea9c ===>
# 1 for 96 seasonality,the site_id b3bf475a-41f8-65a5-08cc-ed0f38aeea9c is seasonal
# 1 for 672 seasonality,the site_id b3bf475a-41f8-65a5-08cc-ed0f38aeea9c  Seasonality could not be identified
# 4549a7e8-4082-a14b-222c-0b3f854d53be ===>
# 1 for 96 seasonality,the site_id 4549a7e8-4082-a14b-222c-0b3f854d53be is seasonal
# 1 for 672 seasonality,the site_id 4549a7e8-4082-a14b-222c-0b3f854d53be  Seasonality could not be identified
# f21e307b-e71c-c4d1-f100-2f5c57d3bdf6 ===>
# 1 for 96 seasonality,the site_id f21e307b-e71c-c4d1-f100-2f5c57d3bdf6 is seasonal
# 1 for 672 seasonality,the site_id f21e307b-e71c-c4d1-f100-2f5c57d3bdf6  Seasonality could not be identified
# eb12b7cb-d680-8321-33a9-806aaef20fd5 ===>
# 1 for 96 seasonality,the site_id eb12b7cb-d680-8321-33a9-806aaef20fd5 is seasonal
# 1 for 672 seasonality,the site_id eb12b7cb-d680-8321-33a9-806aaef20fd5  Seasonality could not be identified
# fadf733b-570c-0e26-247b-f336f42c09d4 ===>
# 1 for 96 seasonality,the site_id fadf733b-570c-0e26-247b-f336f42c09d4 is seasonal
# 1 for 672 seasonality,the site_id fadf733b-570c-0e26-247b-f336f42c09d4  Seasonality could not be identified
# eded4a47-663d-25e0-42a9-1c8d6e2faa41 ===>
# 1 for 96 seasonality,the site_id eded4a47-663d-25e0-42a9-1c8d6e2faa41 is seasonal
# 1 for 672 seasonality,the site_id eded4a47-663d-25e0-42a9-1c8d6e2faa41  Seasonality could not be identified
# 1bc40113-baca-b142-437d-bece746ab8ee ===>
# 1 for 96 seasonality,the site_id 1bc40113-baca-b142-437d-bece746ab8ee is seasonal
# 1 for 672 seasonality,the site_id 1bc40113-baca-b142-437d-bece746ab8ee  Seasonality could not be identified
# b9ad1c9b-fbe2-f36f-ab2a-6894c251433f ===>
# 1 for 96 seasonality,the site_id b9ad1c9b-fbe2-f36f-ab2a-6894c251433f is seasonal
# 1 for 672 seasonality,the site_id b9ad1c9b-fbe2-f36f-ab2a-6894c251433f  Seasonality could not be identified
# 7f275fd8-3ac0-e8ed-ec70-7fda16deb374 ===>
# 1 for 96 seasonality,the site_id 7f275fd8-3ac0-e8ed-ec70-7fda16deb374 is seasonal
# 1 for 672 seasonality,the site_id 7f275fd8-3ac0-e8ed-ec70-7fda16deb374  Seasonality could not be identified
# e55609cd-8ca1-b9ce-58b2-d368dcab8497 ===>
# 1 for 96 seasonality,the site_id e55609cd-8ca1-b9ce-58b2-d368dcab8497 is seasonal
# 1 for 672 seasonality,the site_id e55609cd-8ca1-b9ce-58b2-d368dcab8497  Seasonality could not be identified
# 13845a3d-66cd-aa26-c6e2-b47183f3333b ===>
# 1 for 96 seasonality,the site_id 13845a3d-66cd-aa26-c6e2-b47183f3333b is seasonal
# 1 for 672 seasonality,the site_id 13845a3d-66cd-aa26-c6e2-b47183f3333b  Seasonality could not be identified
# 8af2530d-3c10-9a12-3b3d-ab99979b25b6 ===>
# 1 for 96 seasonality,the site_id 8af2530d-3c10-9a12-3b3d-ab99979b25b6 is seasonal
# 1 for 672 seasonality,the site_id 8af2530d-3c10-9a12-3b3d-ab99979b25b6  Seasonality could not be identified
# 07ae0994-02e6-2b53-051f-609e8d9efa1e ===>
# 0 for 96 seasonality,the site_id 07ae0994-02e6-2b53-051f-609e8d9efa1e  Seasonality could not be identified
# 0 for 672 seasonality,the site_id 07ae0994-02e6-2b53-051f-609e8d9efa1e  Seasonality could not be identified
# c0727430-6446-4ab2-9719-21fad5f6aaf3 ===>
# 1 for 96 seasonality,the site_id c0727430-6446-4ab2-9719-21fad5f6aaf3 is seasonal
# 1 for 672 seasonality,the site_id c0727430-6446-4ab2-9719-21fad5f6aaf3  Seasonality could not be identified
# a31524b6-60b5-5928-887b-263b5cb59c23 ===>
# 1 for 96 seasonality,the site_id a31524b6-60b5-5928-887b-263b5cb59c23 is seasonal
# 1 for 672 seasonality,the site_id a31524b6-60b5-5928-887b-263b5cb59c23  Seasonality could not be identified
# fa27bfb9-9b3e-ace1-bb88-5b95e56f16ba ===>
# 1 for 96 seasonality,the site_id fa27bfb9-9b3e-ace1-bb88-5b95e56f16ba is seasonal
# 1 for 672 seasonality,the site_id fa27bfb9-9b3e-ace1-bb88-5b95e56f16ba  Seasonality could not be identified
# 22cb331d-848f-b8ad-53da-cf16fd4dc49a ===>
# 1 for 96 seasonality,the site_id 22cb331d-848f-b8ad-53da-cf16fd4dc49a is seasonal
# 1 for 672 seasonality,the site_id 22cb331d-848f-b8ad-53da-cf16fd4dc49a  Seasonality could not be identified
# dd0ec801-5e9b-837c-4289-ed168ca81a4f ===>
# 1 for 96 seasonality,the site_id dd0ec801-5e9b-837c-4289-ed168ca81a4f is seasonal
# 1 for 672 seasonality,the site_id dd0ec801-5e9b-837c-4289-ed168ca81a4f  Seasonality could not be identified
# a1dc9b8e-1806-5e10-3b1d-d7db9c3da156 ===>
# 1 for 96 seasonality,the site_id a1dc9b8e-1806-5e10-3b1d-d7db9c3da156 is seasonal
# 1 for 672 seasonality,the site_id a1dc9b8e-1806-5e10-3b1d-d7db9c3da156  Seasonality could not be identified
# 7e03e2ca-18ed-5eb8-15d9-d56ad7d89634 ===>
# 0 for 96 seasonality,the site_id 7e03e2ca-18ed-5eb8-15d9-d56ad7d89634  Seasonality could not be identified
# 0 for 672 seasonality,the site_id 7e03e2ca-18ed-5eb8-15d9-d56ad7d89634  Seasonality could not be identified
# 12e61d30-25f9-16f9-7cfc-c9221a766def ===>
# 1 for 96 seasonality,the site_id 12e61d30-25f9-16f9-7cfc-c9221a766def is seasonal
# 1 for 672 seasonality,the site_id 12e61d30-25f9-16f9-7cfc-c9221a766def  Seasonality could not be identified
# fe6451c9-63c7-b774-496c-9ce8ba6d01af ===>
# 1 for 96 seasonality,the site_id fe6451c9-63c7-b774-496c-9ce8ba6d01af is seasonal
# 1 for 672 seasonality,the site_id fe6451c9-63c7-b774-496c-9ce8ba6d01af  Seasonality could not be identified
# 92b339d1-29c0-d718-8f9e-f38fddb9ed36 ===>
# 1 for 96 seasonality,the site_id 92b339d1-29c0-d718-8f9e-f38fddb9ed36 is seasonal
# 1 for 672 seasonality,the site_id 92b339d1-29c0-d718-8f9e-f38fddb9ed36  Seasonality could not be identified
# ac00b847-21c9-f9d2-2c28-9e28b8a33bf5 ===>
# 1 for 96 seasonality,the site_id ac00b847-21c9-f9d2-2c28-9e28b8a33bf5 is seasonal
# 1 for 672 seasonality,the site_id ac00b847-21c9-f9d2-2c28-9e28b8a33bf5  Seasonality could not be identified
# 16dadab9-bfbb-e945-67ce-6356777c0d48 ===>
# 1 for 96 seasonality,the site_id 16dadab9-bfbb-e945-67ce-6356777c0d48 is seasonal
# 1 for 672 seasonality,the site_id 16dadab9-bfbb-e945-67ce-6356777c0d48  Seasonality could not be identified
# 853e8d46-b872-348a-7bd8-70f5165b3afa ===>
# 1 for 96 seasonality,the site_id 853e8d46-b872-348a-7bd8-70f5165b3afa is seasonal
# 1 for 672 seasonality,the site_id 853e8d46-b872-348a-7bd8-70f5165b3afa  Seasonality could not be identified
# 1a0cadec-1d86-8a5b-4530-e162456163e2 ===>
# 1 for 96 seasonality,the site_id 1a0cadec-1d86-8a5b-4530-e162456163e2 is seasonal
# 1 for 672 seasonality,the site_id 1a0cadec-1d86-8a5b-4530-e162456163e2  Seasonality could not be identified
# 253a7559-7ebb-1c96-609a-df5c5798aabc ===>
# 1 for 96 seasonality,the site_id 253a7559-7ebb-1c96-609a-df5c5798aabc is seasonal
# 1 for 672 seasonality,the site_id 253a7559-7ebb-1c96-609a-df5c5798aabc  Seasonality could not be identified
# 529c6f3e-e942-8be0-cd08-b86ffa210e39 ===>
# 1 for 96 seasonality,the site_id 529c6f3e-e942-8be0-cd08-b86ffa210e39 is seasonal
# 1 for 672 seasonality,the site_id 529c6f3e-e942-8be0-cd08-b86ffa210e39  Seasonality could not be identified
# dc4820b0-76dc-93b1-2f7a-9fa2c5d5c6a8 ===>
# 1 for 96 seasonality,the site_id dc4820b0-76dc-93b1-2f7a-9fa2c5d5c6a8 is seasonal
# 1 for 672 seasonality,the site_id dc4820b0-76dc-93b1-2f7a-9fa2c5d5c6a8  Seasonality could not be identified
# 697f6a9a-ee82-6061-2027-071e657e0e21 ===>
# 1 for 96 seasonality,the site_id 697f6a9a-ee82-6061-2027-071e657e0e21 is seasonal
# 1 for 672 seasonality,the site_id 697f6a9a-ee82-6061-2027-071e657e0e21  Seasonality could not be identified
# 64d71a56-74d5-f7c0-4977-1a90d44b3f1e ===>
# 1 for 96 seasonality,the site_id 64d71a56-74d5-f7c0-4977-1a90d44b3f1e is seasonal
# 1 for 672 seasonality,the site_id 64d71a56-74d5-f7c0-4977-1a90d44b3f1e  Seasonality could not be identified
# 9acc0d29-71e3-007f-0417-e051f2ab4ae6 ===>
# 1 for 96 seasonality,the site_id 9acc0d29-71e3-007f-0417-e051f2ab4ae6 is seasonal
# 1 for 672 seasonality,the site_id 9acc0d29-71e3-007f-0417-e051f2ab4ae6  Seasonality could not be identified
# 8947e567-4ae2-7228-69a4-2a7b8b90e679 ===>
# 1 for 96 seasonality,the site_id 8947e567-4ae2-7228-69a4-2a7b8b90e679 is seasonal
# 1 for 672 seasonality,the site_id 8947e567-4ae2-7228-69a4-2a7b8b90e679  Seasonality could not be identified
# 678558e3-3fd0-d054-e17f-f0defcb52c12 ===>
# 1 for 96 seasonality,the site_id 678558e3-3fd0-d054-e17f-f0defcb52c12 is seasonal
# 1 for 672 seasonality,the site_id 678558e3-3fd0-d054-e17f-f0defcb52c12  Seasonality could not be identified
# 2dfc25b7-004e-72e8-b4b1-852d2fd2242e ===>
# 1 for 96 seasonality,the site_id 2dfc25b7-004e-72e8-b4b1-852d2fd2242e is seasonal
# 1 for 672 seasonality,the site_id 2dfc25b7-004e-72e8-b4b1-852d2fd2242e  Seasonality could not be identified
# e1936d00-255f-5073-fe4a-c0db2543150e ===>
# 1 for 96 seasonality,the site_id e1936d00-255f-5073-fe4a-c0db2543150e is seasonal
# 1 for 672 seasonality,the site_id e1936d00-255f-5073-fe4a-c0db2543150e  Seasonality could not be identified
# 3798bec0-bb4f-e581-d9e4-8741c99af207 ===>
# 1 for 96 seasonality,the site_id 3798bec0-bb4f-e581-d9e4-8741c99af207 is seasonal
# 1 for 672 seasonality,the site_id 3798bec0-bb4f-e581-d9e4-8741c99af207  Seasonality could not be identified
# d342df32-ed32-cb36-edd3-345e2feab911 ===>
# 1 for 96 seasonality,the site_id d342df32-ed32-cb36-edd3-345e2feab911 is seasonal
# 1 for 672 seasonality,the site_id d342df32-ed32-cb36-edd3-345e2feab911  Seasonality could not be identified
# 9705b57a-ff74-2e7e-9f3a-a3a3e1153153 ===>
# 1 for 96 seasonality,the site_id 9705b57a-ff74-2e7e-9f3a-a3a3e1153153 is seasonal
# 1 for 672 seasonality,the site_id 9705b57a-ff74-2e7e-9f3a-a3a3e1153153  Seasonality could not be identified
# f8d4dfa0-e065-be62-96c0-02e7792268fd ===>
# 1 for 96 seasonality,the site_id f8d4dfa0-e065-be62-96c0-02e7792268fd is seasonal
# 1 for 672 seasonality,the site_id f8d4dfa0-e065-be62-96c0-02e7792268fd  Seasonality could not be identified
# 77d8e15e-f938-9abc-285a-0fa8eab46953 ===>
# 1 for 96 seasonality,the site_id 77d8e15e-f938-9abc-285a-0fa8eab46953 is seasonal
# 1 for 672 seasonality,the site_id 77d8e15e-f938-9abc-285a-0fa8eab46953  Seasonality could not be identified
# cb1b1692-26f3-ec9b-9551-d949d309fa4c ===>
# 1 for 96 seasonality,the site_id cb1b1692-26f3-ec9b-9551-d949d309fa4c is seasonal
# 1 for 672 seasonality,the site_id cb1b1692-26f3-ec9b-9551-d949d309fa4c  Seasonality could not be identified
# 6d170a51-75d7-e03a-6464-cf3784b0e5b9 ===>
# 1 for 96 seasonality,the site_id 6d170a51-75d7-e03a-6464-cf3784b0e5b9 is seasonal
# 1 for 672 seasonality,the site_id 6d170a51-75d7-e03a-6464-cf3784b0e5b9  Seasonality could not be identified
# 3ec5215e-d1ec-ec60-ddd0-905fbbf03bb9 ===>
# 1 for 96 seasonality,the site_id 3ec5215e-d1ec-ec60-ddd0-905fbbf03bb9 is seasonal
# 1 for 672 seasonality,the site_id 3ec5215e-d1ec-ec60-ddd0-905fbbf03bb9  Seasonality could not be identified
# 0e2a25a4-9b96-ac1c-d17d-a4228c6682fb ===>
# 1 for 96 seasonality,the site_id 0e2a25a4-9b96-ac1c-d17d-a4228c6682fb is seasonal
# 1 for 672 seasonality,the site_id 0e2a25a4-9b96-ac1c-d17d-a4228c6682fb  Seasonality could not be identified
# 27dd4c7b-5795-4fb9-4d4c-a522697c75a3 ===>
# 1 for 96 seasonality,the site_id 27dd4c7b-5795-4fb9-4d4c-a522697c75a3 is seasonal
# 1 for 672 seasonality,the site_id 27dd4c7b-5795-4fb9-4d4c-a522697c75a3  Seasonality could not be identified
# c4fdaadd-0618-bb7d-830a-fbc7b15cb884 ===>
# 1 for 96 seasonality,the site_id c4fdaadd-0618-bb7d-830a-fbc7b15cb884 is seasonal
# 1 for 672 seasonality,the site_id c4fdaadd-0618-bb7d-830a-fbc7b15cb884  Seasonality could not be identified
# 943cb502-9e81-3890-568d-1c378ef503de ===>
# 1 for 96 seasonality,the site_id 943cb502-9e81-3890-568d-1c378ef503de is seasonal
# 1 for 672 seasonality,the site_id 943cb502-9e81-3890-568d-1c378ef503de  Seasonality could not be identified
# c1cb8652-f39a-189e-25cf-7d6313a9b01f ===>
# 1 for 96 seasonality,the site_id c1cb8652-f39a-189e-25cf-7d6313a9b01f is seasonal
# 1 for 672 seasonality,the site_id c1cb8652-f39a-189e-25cf-7d6313a9b01f  Seasonality could not be identified
# f4f3d175-b8b7-3445-1b67-676bf56c5679 ===>
# 1 for 96 seasonality,the site_id f4f3d175-b8b7-3445-1b67-676bf56c5679 is seasonal
# 1 for 672 seasonality,the site_id f4f3d175-b8b7-3445-1b67-676bf56c5679  Seasonality could not be identified
# 15de2373-6944-3d69-32bc-e8cd5d7cca3a ===>
# 1 for 96 seasonality,the site_id 15de2373-6944-3d69-32bc-e8cd5d7cca3a is seasonal
# 1 for 672 seasonality,the site_id 15de2373-6944-3d69-32bc-e8cd5d7cca3a  Seasonality could not be identified
# c24f74e9-aa99-2b51-7679-dd1b0ef5adc9 ===>
# 1 for 96 seasonality,the site_id c24f74e9-aa99-2b51-7679-dd1b0ef5adc9 is seasonal
# 1 for 672 seasonality,the site_id c24f74e9-aa99-2b51-7679-dd1b0ef5adc9  Seasonality could not be identified
# 15739bd4-b7b4-6d3c-f948-859c6dc09bdc ===>
# 1 for 96 seasonality,the site_id 15739bd4-b7b4-6d3c-f948-859c6dc09bdc is seasonal
# 1 for 672 seasonality,the site_id 15739bd4-b7b4-6d3c-f948-859c6dc09bdc  Seasonality could not be identified
# 8c0761fe-dba5-158c-e5be-bb8aa0f6d07a ===>
# 1 for 96 seasonality,the site_id 8c0761fe-dba5-158c-e5be-bb8aa0f6d07a is seasonal
# 1 for 672 seasonality,the site_id 8c0761fe-dba5-158c-e5be-bb8aa0f6d07a  Seasonality could not be identified
# fb4fbc9d-bef2-9755-cf57-e481f4cbc83c ===>
# 1 for 96 seasonality,the site_id fb4fbc9d-bef2-9755-cf57-e481f4cbc83c is seasonal
# 1 for 672 seasonality,the site_id fb4fbc9d-bef2-9755-cf57-e481f4cbc83c  Seasonality could not be identified
# 478fe98a-0473-bebd-03cd-0d7ae3af595e ===>
# 1 for 96 seasonality,the site_id 478fe98a-0473-bebd-03cd-0d7ae3af595e is seasonal
# 1 for 672 seasonality,the site_id 478fe98a-0473-bebd-03cd-0d7ae3af595e  Seasonality could not be identified
# 2f29f8bd-e419-5941-4d9b-1e45d72f84a0 ===>
# 1 for 96 seasonality,the site_id 2f29f8bd-e419-5941-4d9b-1e45d72f84a0 is seasonal
# 1 for 672 seasonality,the site_id 2f29f8bd-e419-5941-4d9b-1e45d72f84a0  Seasonality could not be identified
# dea23cf8-66c2-40ca-586d-6ba00361f1cd ===>
# 1 for 96 seasonality,the site_id dea23cf8-66c2-40ca-586d-6ba00361f1cd is seasonal
# 1 for 672 seasonality,the site_id dea23cf8-66c2-40ca-586d-6ba00361f1cd  Seasonality could not be identified
# 55245d41-a763-7bbd-22d9-7eae53359846 ===>
# 1 for 96 seasonality,the site_id 55245d41-a763-7bbd-22d9-7eae53359846 is seasonal
# 1 for 672 seasonality,the site_id 55245d41-a763-7bbd-22d9-7eae53359846  Seasonality could not be identified
# d7de778a-833f-c75e-df25-dadcaea87332 ===>
# 1 for 96 seasonality,the site_id d7de778a-833f-c75e-df25-dadcaea87332 is seasonal
# 1 for 672 seasonality,the site_id d7de778a-833f-c75e-df25-dadcaea87332  Seasonality could not be identified
# feda0965-ac85-b46a-77fe-dc2ad48772fe ===>
# 1 for 96 seasonality,the site_id feda0965-ac85-b46a-77fe-dc2ad48772fe is seasonal
# 1 for 672 seasonality,the site_id feda0965-ac85-b46a-77fe-dc2ad48772fe  Seasonality could not be identified
# 692d66d9-f8e7-5a6e-af7e-7983d9a6d0e1 ===>
# 1 for 96 seasonality,the site_id 692d66d9-f8e7-5a6e-af7e-7983d9a6d0e1 is seasonal
# 1 for 672 seasonality,the site_id 692d66d9-f8e7-5a6e-af7e-7983d9a6d0e1  Seasonality could not be identified
# 204160be-4479-553f-01c9-a7ac934dde3e ===>
# 1 for 96 seasonality,the site_id 204160be-4479-553f-01c9-a7ac934dde3e is seasonal
# 1 for 672 seasonality,the site_id 204160be-4479-553f-01c9-a7ac934dde3e  Seasonality could not be identified
# 6f245a0a-eff7-e9fe-bb95-8d0270a775cf ===>
# 1 for 96 seasonality,the site_id 6f245a0a-eff7-e9fe-bb95-8d0270a775cf is seasonal
# 1 for 672 seasonality,the site_id 6f245a0a-eff7-e9fe-bb95-8d0270a775cf  Seasonality could not be identified
# 72b59214-5b0e-b47b-36e5-f6ede6a8d160 ===>
# 1 for 96 seasonality,the site_id 72b59214-5b0e-b47b-36e5-f6ede6a8d160 is seasonal
# 1 for 672 seasonality,the site_id 72b59214-5b0e-b47b-36e5-f6ede6a8d160  Seasonality could not be identified
# 872ba917-1c97-07f5-b619-742a535d3f45 ===>
# 1 for 96 seasonality,the site_id 872ba917-1c97-07f5-b619-742a535d3f45 is seasonal
# 1 for 672 seasonality,the site_id 872ba917-1c97-07f5-b619-742a535d3f45  Seasonality could not be identified
# 7beee54b-ea35-d1d2-c01f-1869a880773a ===>
# 1 for 96 seasonality,the site_id 7beee54b-ea35-d1d2-c01f-1869a880773a is seasonal
# 1 for 672 seasonality,the site_id 7beee54b-ea35-d1d2-c01f-1869a880773a  Seasonality could not be identified
# e849b316-0bd6-e691-4ebc-ce098ad8435d ===>
# 1 for 96 seasonality,the site_id e849b316-0bd6-e691-4ebc-ce098ad8435d is seasonal
# 1 for 672 seasonality,the site_id e849b316-0bd6-e691-4ebc-ce098ad8435d  Seasonality could not be identified
# eadfee31-e99a-f2af-0975-37d3e9b39af3 ===>
# 1 for 96 seasonality,the site_id eadfee31-e99a-f2af-0975-37d3e9b39af3 is seasonal
# 1 for 672 seasonality,the site_id eadfee31-e99a-f2af-0975-37d3e9b39af3  Seasonality could not be identified
# 6f493bda-5d1e-6dac-2438-2f79d51b7c6e ===>
# 1 for 96 seasonality,the site_id 6f493bda-5d1e-6dac-2438-2f79d51b7c6e is seasonal
# 1 for 672 seasonality,the site_id 6f493bda-5d1e-6dac-2438-2f79d51b7c6e  Seasonality could not be identified
# 2c3dd4f7-7ab3-a0e8-4485-0e295050abd5 ===>
# 1 for 96 seasonality,the site_id 2c3dd4f7-7ab3-a0e8-4485-0e295050abd5 is seasonal
# 1 for 672 seasonality,the site_id 2c3dd4f7-7ab3-a0e8-4485-0e295050abd5  Seasonality could not be identified
# 0359f57d-5a06-40c6-3d83-4a0a7720eba1 ===>
# 1 for 96 seasonality,the site_id 0359f57d-5a06-40c6-3d83-4a0a7720eba1 is seasonal
# 1 for 672 seasonality,the site_id 0359f57d-5a06-40c6-3d83-4a0a7720eba1  Seasonality could not be identified
# ebe99dd0-da49-66b2-cd2e-e79dab5e45c5 ===>
# 1 for 96 seasonality,the site_id ebe99dd0-da49-66b2-cd2e-e79dab5e45c5 is seasonal
# 1 for 672 seasonality,the site_id ebe99dd0-da49-66b2-cd2e-e79dab5e45c5  Seasonality could not be identified
# cb8d68c3-d6e6-215a-eca2-b969bed491af ===>
# 0 for 96 seasonality,the site_id cb8d68c3-d6e6-215a-eca2-b969bed491af  Seasonality could not be identified
# 0 for 672 seasonality,the site_id cb8d68c3-d6e6-215a-eca2-b969bed491af  Seasonality could not be identified
# 6f375f3e-7bc8-3b7f-e3bd-77378d0c22c7 ===>
# 1 for 96 seasonality,the site_id 6f375f3e-7bc8-3b7f-e3bd-77378d0c22c7 is seasonal
# 2 for 672 seasonality,the site_id 6f375f3e-7bc8-3b7f-e3bd-77378d0c22c7 is seasonal
# 5fe94934-6a5f-af51-9794-5b881e7adf19 ===>
# 1 for 96 seasonality,the site_id 5fe94934-6a5f-af51-9794-5b881e7adf19 is seasonal
# 1 for 672 seasonality,the site_id 5fe94934-6a5f-af51-9794-5b881e7adf19  Seasonality could not be identified
# 15790985-7b3c-8665-72be-4a829cd30c03 ===>
# 0 for 96 seasonality,the site_id 15790985-7b3c-8665-72be-4a829cd30c03  Seasonality could not be identified
# 0 for 672 seasonality,the site_id 15790985-7b3c-8665-72be-4a829cd30c03  Seasonality could not be identified
# 39b6927a-be1b-dace-b129-5c7dc7fccb9b ===>
# 0 for 96 seasonality,the site_id 39b6927a-be1b-dace-b129-5c7dc7fccb9b  Seasonality could not be identified
# 1 for 672 seasonality,the site_id 39b6927a-be1b-dace-b129-5c7dc7fccb9b is seasonal
# a05598bc-59ac-6697-0673-0e87e7ccc677 ===>
# 0 for 96 seasonality,the site_id a05598bc-59ac-6697-0673-0e87e7ccc677  Seasonality could not be identified
# 1 for 672 seasonality,the site_id a05598bc-59ac-6697-0673-0e87e7ccc677 is seasonal
# 8c5573ab-4066-3a42-8b0b-2b9dba5533a8 ===>
# 1 for 96 seasonality,the site_id 8c5573ab-4066-3a42-8b0b-2b9dba5533a8 is seasonal
# 2 for 672 seasonality,the site_id 8c5573ab-4066-3a42-8b0b-2b9dba5533a8 is seasonal
# f6e2d393-450d-b1ed-2a0a-8b1dc84acae9 ===>
# 1 for 96 seasonality,the site_id f6e2d393-450d-b1ed-2a0a-8b1dc84acae9 is seasonal
# 1 for 672 seasonality,the site_id f6e2d393-450d-b1ed-2a0a-8b1dc84acae9  Seasonality could not be identified
# 8dc748b2-5f31-e7b9-c1e1-2174f9637a12 ===>
# 1 for 96 seasonality,the site_id 8dc748b2-5f31-e7b9-c1e1-2174f9637a12 is seasonal
# 1 for 672 seasonality,the site_id 8dc748b2-5f31-e7b9-c1e1-2174f9637a12  Seasonality could not be identified
# 5765f8aa-b69b-a03f-7cf5-560bc216929e ===>
# 1 for 96 seasonality,the site_id 5765f8aa-b69b-a03f-7cf5-560bc216929e is seasonal
# 1 for 672 seasonality,the site_id 5765f8aa-b69b-a03f-7cf5-560bc216929e  Seasonality could not be identified
# c25074ec-d72c-f37c-b123-8140a125ed6d ===>
# 1 for 96 seasonality,the site_id c25074ec-d72c-f37c-b123-8140a125ed6d is seasonal
# 1 for 672 seasonality,the site_id c25074ec-d72c-f37c-b123-8140a125ed6d  Seasonality could not be identified
# 9bb9a945-20d9-1b7e-0855-6bccef786e2b ===>
# 1 for 96 seasonality,the site_id 9bb9a945-20d9-1b7e-0855-6bccef786e2b is seasonal
# 2 for 672 seasonality,the site_id 9bb9a945-20d9-1b7e-0855-6bccef786e2b is seasonal
# 871fe49b-fe9e-b4f9-dbef-5054703fcd68 ===>
# 1 for 96 seasonality,the site_id 871fe49b-fe9e-b4f9-dbef-5054703fcd68 is seasonal
# 2 for 672 seasonality,the site_id 871fe49b-fe9e-b4f9-dbef-5054703fcd68 is seasonal
# ad585ec9-a1c9-e319-1481-954f34579ac3 ===>
# 1 for 96 seasonality,the site_id ad585ec9-a1c9-e319-1481-954f34579ac3 is seasonal
# 1 for 672 seasonality,the site_id ad585ec9-a1c9-e319-1481-954f34579ac3  Seasonality could not be identified
# eb2e47c5-d6ee-9ece-ee1c-a07c8fdc58ef ===>
# 1 for 96 seasonality,the site_id eb2e47c5-d6ee-9ece-ee1c-a07c8fdc58ef is seasonal
# 1 for 672 seasonality,the site_id eb2e47c5-d6ee-9ece-ee1c-a07c8fdc58ef  Seasonality could not be identified
# 65a25cea-b6e7-95c5-d9e2-0bd9041ae4b5 ===>
# 1 for 96 seasonality,the site_id 65a25cea-b6e7-95c5-d9e2-0bd9041ae4b5 is seasonal
# 1 for 672 seasonality,the site_id 65a25cea-b6e7-95c5-d9e2-0bd9041ae4b5  Seasonality could not be identified
# 97a1a970-21c0-c946-f82b-e1b58b530cc3 ===>
# 1 for 96 seasonality,the site_id 97a1a970-21c0-c946-f82b-e1b58b530cc3 is seasonal
# 1 for 672 seasonality,the site_id 97a1a970-21c0-c946-f82b-e1b58b530cc3  Seasonality could not be identified
# a44429a8-e76c-8e7e-ec61-66872241de67 ===>
# 0 for 96 seasonality,the site_id a44429a8-e76c-8e7e-ec61-66872241de67  Seasonality could not be identified
# 1 for 672 seasonality,the site_id a44429a8-e76c-8e7e-ec61-66872241de67 is seasonal
# 9aa3b5ad-0981-1a44-d58d-e3f2d1f2d550 ===>
# 0 for 96 seasonality,the site_id 9aa3b5ad-0981-1a44-d58d-e3f2d1f2d550  Seasonality could not be identified
# 1 for 672 seasonality,the site_id 9aa3b5ad-0981-1a44-d58d-e3f2d1f2d550 is seasonal
# bb6d4ebb-6353-7fca-87f2-d4edbf573fcc ===>
# 1 for 96 seasonality,the site_id bb6d4ebb-6353-7fca-87f2-d4edbf573fcc is seasonal
# 2 for 672 seasonality,the site_id bb6d4ebb-6353-7fca-87f2-d4edbf573fcc is seasonal
# ea0bee90-5500-25e3-1483-5ca53f8b0d82 ===>
# 1 for 96 seasonality,the site_id ea0bee90-5500-25e3-1483-5ca53f8b0d82 is seasonal
# 2 for 672 seasonality,the site_id ea0bee90-5500-25e3-1483-5ca53f8b0d82 is seasonal
# a075bba6-b74c-d462-7462-0020ac636a3f ===>
# 1 for 96 seasonality,the site_id a075bba6-b74c-d462-7462-0020ac636a3f is seasonal
# 2 for 672 seasonality,the site_id a075bba6-b74c-d462-7462-0020ac636a3f is seasonal
# 3521b8a1-da99-25d8-a6eb-afc16bf58e5c ===>
# 1 for 96 seasonality,the site_id 3521b8a1-da99-25d8-a6eb-afc16bf58e5c is seasonal
# 2 for 672 seasonality,the site_id 3521b8a1-da99-25d8-a6eb-afc16bf58e5c is seasonal
# 6ba0dc29-c307-1388-1637-85349f4e0309 ===>
# 0 for 96 seasonality,the site_id 6ba0dc29-c307-1388-1637-85349f4e0309  Seasonality could not be identified
# 1 for 672 seasonality,the site_id 6ba0dc29-c307-1388-1637-85349f4e0309 is seasonal
# 13479e32-59f4-97af-2eca-cd296832c088 ===>
# 1 for 96 seasonality,the site_id 13479e32-59f4-97af-2eca-cd296832c088 is seasonal
# 1 for 672 seasonality,the site_id 13479e32-59f4-97af-2eca-cd296832c088  Seasonality could not be identified
# 144d755b-c75f-ac00-b584-fe73a6f24bcb ===>
# 1 for 96 seasonality,the site_id 144d755b-c75f-ac00-b584-fe73a6f24bcb is seasonal
# 1 for 672 seasonality,the site_id 144d755b-c75f-ac00-b584-fe73a6f24bcb  Seasonality could not be identified
# 32783053-66b1-44e3-c3a9-0010749b35c9 ===>
# 1 for 96 seasonality,the site_id 32783053-66b1-44e3-c3a9-0010749b35c9 is seasonal
# 1 for 672 seasonality,the site_id 32783053-66b1-44e3-c3a9-0010749b35c9  Seasonality could not be identified
# 5aed4954-460d-a724-04bc-522537a29698 ===>
# 0 for 96 seasonality,the site_id 5aed4954-460d-a724-04bc-522537a29698  Seasonality could not be identified
# 0 for 672 seasonality,the site_id 5aed4954-460d-a724-04bc-522537a29698  Seasonality could not be identified
# 994cc087-b7a6-95cb-30f2-dfeab0d54625 ===>
# 1 for 96 seasonality,the site_id 994cc087-b7a6-95cb-30f2-dfeab0d54625 is seasonal
# 1 for 672 seasonality,the site_id 994cc087-b7a6-95cb-30f2-dfeab0d54625  Seasonality could not be identified
# 81e23cd9-b29e-f3c3-464a-f3c7aae48cb9 ===>
# 1 for 96 seasonality,the site_id 81e23cd9-b29e-f3c3-464a-f3c7aae48cb9 is seasonal
# 1 for 672 seasonality,the site_id 81e23cd9-b29e-f3c3-464a-f3c7aae48cb9  Seasonality could not be identified
# 9e5958d7-e707-bb5f-826a-2ee8c17bf297 ===>
# 1 for 96 seasonality,the site_id 9e5958d7-e707-bb5f-826a-2ee8c17bf297 is seasonal
# 1 for 672 seasonality,the site_id 9e5958d7-e707-bb5f-826a-2ee8c17bf297  Seasonality could not be identified
# 5961e490-81ba-c338-86cd-ad5c7919ee60 ===>
# 1 for 96 seasonality,the site_id 5961e490-81ba-c338-86cd-ad5c7919ee60 is seasonal
# 1 for 672 seasonality,the site_id 5961e490-81ba-c338-86cd-ad5c7919ee60  Seasonality could not be identified
# a03f0e3d-e65c-be54-d81f-8d29058cada5 ===>
# 1 for 96 seasonality,the site_id a03f0e3d-e65c-be54-d81f-8d29058cada5 is seasonal
# 1 for 672 seasonality,the site_id a03f0e3d-e65c-be54-d81f-8d29058cada5  Seasonality could not be identified
# cc7bb9d3-3ef7-979e-1603-70fa8dbcb70e ===>
# 1 for 96 seasonality,the site_id cc7bb9d3-3ef7-979e-1603-70fa8dbcb70e is seasonal
# 1 for 672 seasonality,the site_id cc7bb9d3-3ef7-979e-1603-70fa8dbcb70e  Seasonality could not be identified
# 5a717cb9-181c-1d40-e12f-a2777bc78952 ===>
# 1 for 96 seasonality,the site_id 5a717cb9-181c-1d40-e12f-a2777bc78952 is seasonal
# 1 for 672 seasonality,the site_id 5a717cb9-181c-1d40-e12f-a2777bc78952  Seasonality could not be identified
# de6f7118-06d2-45e8-1a7a-b30e07e233f7 ===>
# 1 for 96 seasonality,the site_id de6f7118-06d2-45e8-1a7a-b30e07e233f7 is seasonal
# 1 for 672 seasonality,the site_id de6f7118-06d2-45e8-1a7a-b30e07e233f7  Seasonality could not be identified
# 5262ce23-8185-85d4-08d2-0a7fe031f563 ===>
# 1 for 96 seasonality,the site_id 5262ce23-8185-85d4-08d2-0a7fe031f563 is seasonal
# 1 for 672 seasonality,the site_id 5262ce23-8185-85d4-08d2-0a7fe031f563  Seasonality could not be identified
# a85566bd-7cea-eb51-6aa5-912ee6bdd7d7 ===>
# 0 for 96 seasonality,the site_id a85566bd-7cea-eb51-6aa5-912ee6bdd7d7  Seasonality could not be identified
# 0 for 672 seasonality,the site_id a85566bd-7cea-eb51-6aa5-912ee6bdd7d7  Seasonality could not be identified
# d0ccf0f8-69c7-66ad-1921-c922871b82f1 ===>
# 1 for 96 seasonality,the site_id d0ccf0f8-69c7-66ad-1921-c922871b82f1 is seasonal
# 1 for 672 seasonality,the site_id d0ccf0f8-69c7-66ad-1921-c922871b82f1  Seasonality could not be identified
# 6583ed22-8aa7-bfa3-b07d-ee47898e9a60 ===>
# 1 for 96 seasonality,the site_id 6583ed22-8aa7-bfa3-b07d-ee47898e9a60 is seasonal
# 2 for 672 seasonality,the site_id 6583ed22-8aa7-bfa3-b07d-ee47898e9a60 is seasonal
# 9a6fb8f6-21fc-e8a0-aa74-52ca121a14a3 ===>
# 0 for 96 seasonality,the site_id 9a6fb8f6-21fc-e8a0-aa74-52ca121a14a3  Seasonality could not be identified
# 1 for 672 seasonality,the site_id 9a6fb8f6-21fc-e8a0-aa74-52ca121a14a3 is seasonal
# 02f4e241-53ef-7fb8-ff1d-ba17643d7645 ===>
# 1 for 96 seasonality,the site_id 02f4e241-53ef-7fb8-ff1d-ba17643d7645 is seasonal
# 2 for 672 seasonality,the site_id 02f4e241-53ef-7fb8-ff1d-ba17643d7645 is seasonal
# 62bca157-801c-d9df-de16-8d9b286db265 ===>
# 1 for 96 seasonality,the site_id 62bca157-801c-d9df-de16-8d9b286db265 is seasonal
# 2 for 672 seasonality,the site_id 62bca157-801c-d9df-de16-8d9b286db265 is seasonal
# d7c0b775-cb72-d1d7-341e-92e849c6556e ===>
# 1 for 96 seasonality,the site_id d7c0b775-cb72-d1d7-341e-92e849c6556e is seasonal
# 1 for 672 seasonality,the site_id d7c0b775-cb72-d1d7-341e-92e849c6556e  Seasonality could not be identified
# 69027f73-bb42-a1d3-c29a-2f4c2fabd2f6 ===>
# 1 for 96 seasonality,the site_id 69027f73-bb42-a1d3-c29a-2f4c2fabd2f6 is seasonal
# 1 for 672 seasonality,the site_id 69027f73-bb42-a1d3-c29a-2f4c2fabd2f6  Seasonality could not be identified
# 7bbf216b-e46a-70c5-2359-87e5fdc86737 ===>
# 1 for 96 seasonality,the site_id 7bbf216b-e46a-70c5-2359-87e5fdc86737 is seasonal
# 2 for 672 seasonality,the site_id 7bbf216b-e46a-70c5-2359-87e5fdc86737 is seasonal
# 73fcb689-2e04-1eb9-c81d-0716fd27bfea ===>
# 1 for 96 seasonality,the site_id 73fcb689-2e04-1eb9-c81d-0716fd27bfea is seasonal
# 1 for 672 seasonality,the site_id 73fcb689-2e04-1eb9-c81d-0716fd27bfea  Seasonality could not be identified
# 281e2b26-89bc-2a2c-f5b7-322f942d139d ===>
# 1 for 96 seasonality,the site_id 281e2b26-89bc-2a2c-f5b7-322f942d139d is seasonal
# 2 for 672 seasonality,the site_id 281e2b26-89bc-2a2c-f5b7-322f942d139d is seasonal
# 0644edc0-0417-d12c-b3cb-505bc2e3e258 ===>
# 1 for 96 seasonality,the site_id 0644edc0-0417-d12c-b3cb-505bc2e3e258 is seasonal
# 2 for 672 seasonality,the site_id 0644edc0-0417-d12c-b3cb-505bc2e3e258 is seasonal
# cd72b978-a4fa-c81e-6e90-14892bde8473 ===>
# 1 for 96 seasonality,the site_id cd72b978-a4fa-c81e-6e90-14892bde8473 is seasonal
# 2 for 672 seasonality,the site_id cd72b978-a4fa-c81e-6e90-14892bde8473 is seasonal
# 1c82b217-174d-63af-01b2-2e0d35c85cd2 ===>
# 1 for 96 seasonality,the site_id 1c82b217-174d-63af-01b2-2e0d35c85cd2 is seasonal
# 1 for 672 seasonality,the site_id 1c82b217-174d-63af-01b2-2e0d35c85cd2  Seasonality could not be identified
# 42c0a431-7e11-212b-ce75-b13e7ea4338c ===>
# 1 for 96 seasonality,the site_id 42c0a431-7e11-212b-ce75-b13e7ea4338c is seasonal
# 2 for 672 seasonality,the site_id 42c0a431-7e11-212b-ce75-b13e7ea4338c is seasonal
# a3af4ff8-d1aa-331b-d3fd-814b84257c56 ===>
# 1 for 96 seasonality,the site_id a3af4ff8-d1aa-331b-d3fd-814b84257c56 is seasonal
# 2 for 672 seasonality,the site_id a3af4ff8-d1aa-331b-d3fd-814b84257c56 is seasonal
# 08737ad9-2384-03d2-6557-83958fc5d881 ===>
# 1 for 96 seasonality,the site_id 08737ad9-2384-03d2-6557-83958fc5d881 is seasonal
# 2 for 672 seasonality,the site_id 08737ad9-2384-03d2-6557-83958fc5d881 is seasonal
# debc4593-d7e7-c1ae-f268-f6944c531e3f ===>
# 1 for 96 seasonality,the site_id debc4593-d7e7-c1ae-f268-f6944c531e3f is seasonal
# 2 for 672 seasonality,the site_id debc4593-d7e7-c1ae-f268-f6944c531e3f is seasonal
# 28c08889-a891-54e1-6b6c-bf685b9ee343 ===>
# 1 for 96 seasonality,the site_id 28c08889-a891-54e1-6b6c-bf685b9ee343 is seasonal
# 1 for 672 seasonality,the site_id 28c08889-a891-54e1-6b6c-bf685b9ee343  Seasonality could not be identified
# f58c29d4-da39-b21a-6280-579f4b04af08 ===>
# 1 for 96 seasonality,the site_id f58c29d4-da39-b21a-6280-579f4b04af08 is seasonal
# 1 for 672 seasonality,the site_id f58c29d4-da39-b21a-6280-579f4b04af08  Seasonality could not be identified
# ceecdd19-18fd-a6ed-ddd0-30f2a6af6b5b ===>
# 1 for 96 seasonality,the site_id ceecdd19-18fd-a6ed-ddd0-30f2a6af6b5b is seasonal
# 2 for 672 seasonality,the site_id ceecdd19-18fd-a6ed-ddd0-30f2a6af6b5b is seasonal
# 71cd23cb-cf0c-1c17-8bee-3d5e0eaf60f2 ===>
# 0 for 96 seasonality,the site_id 71cd23cb-cf0c-1c17-8bee-3d5e0eaf60f2  Seasonality could not be identified
# 1 for 672 seasonality,the site_id 71cd23cb-cf0c-1c17-8bee-3d5e0eaf60f2 is seasonal
# 8a2629e5-183b-05c3-7544-5ac89ee3c347 ===>
# 1 for 96 seasonality,the site_id 8a2629e5-183b-05c3-7544-5ac89ee3c347 is seasonal
# 2 for 672 seasonality,the site_id 8a2629e5-183b-05c3-7544-5ac89ee3c347 is seasonal
# d32b4c15-3db3-17b3-20b5-1b982af6f80a ===>
# 1 for 96 seasonality,the site_id d32b4c15-3db3-17b3-20b5-1b982af6f80a is seasonal
# 1 for 672 seasonality,the site_id d32b4c15-3db3-17b3-20b5-1b982af6f80a  Seasonality could not be identified
# b82aebf4-cfa1-5bf5-f3e2-170fbc34dcdf ===>
# 1 for 96 seasonality,the site_id b82aebf4-cfa1-5bf5-f3e2-170fbc34dcdf is seasonal
# 1 for 672 seasonality,the site_id b82aebf4-cfa1-5bf5-f3e2-170fbc34dcdf  Seasonality could not be identified
# fb203000-0b6e-e587-0168-25b53c60a153 ===>
# 1 for 96 seasonality,the site_id fb203000-0b6e-e587-0168-25b53c60a153 is seasonal
# 1 for 672 seasonality,the site_id fb203000-0b6e-e587-0168-25b53c60a153  Seasonality could not be identified
# 2922b8f4-0c8c-16a2-cba4-552feed97df0 ===>
# 1 for 96 seasonality,the site_id 2922b8f4-0c8c-16a2-cba4-552feed97df0 is seasonal
# 1 for 672 seasonality,the site_id 2922b8f4-0c8c-16a2-cba4-552feed97df0  Seasonality could not be identified
# ed4fb335-0c11-b221-7406-1135ae781438 ===>
# 1 for 96 seasonality,the site_id ed4fb335-0c11-b221-7406-1135ae781438 is seasonal
# 1 for 672 seasonality,the site_id ed4fb335-0c11-b221-7406-1135ae781438  Seasonality could not be identified
# 7fca1784-4d99-673e-8ddd-88952202ac35 ===>
# 1 for 96 seasonality,the site_id 7fca1784-4d99-673e-8ddd-88952202ac35 is seasonal
# 1 for 672 seasonality,the site_id 7fca1784-4d99-673e-8ddd-88952202ac35  Seasonality could not be identified
# e5d06e7f-d057-24d9-b417-118c206cbd7e ===>
# 1 for 96 seasonality,the site_id e5d06e7f-d057-24d9-b417-118c206cbd7e is seasonal
# 1 for 672 seasonality,the site_id e5d06e7f-d057-24d9-b417-118c206cbd7e  Seasonality could not be identified
# b9564e11-9942-536d-c540-6a9173e63456 ===>
# 1 for 96 seasonality,the site_id b9564e11-9942-536d-c540-6a9173e63456 is seasonal
# 1 for 672 seasonality,the site_id b9564e11-9942-536d-c540-6a9173e63456  Seasonality could not be identified
# d5e319d6-b7e6-f902-8aa7-a740ffdf3ef6 ===>
# 1 for 96 seasonality,the site_id d5e319d6-b7e6-f902-8aa7-a740ffdf3ef6 is seasonal
# 1 for 672 seasonality,the site_id d5e319d6-b7e6-f902-8aa7-a740ffdf3ef6  Seasonality could not be identified
# a83e1a23-bef7-4772-76ff-b72a3e64726c ===>
# 1 for 96 seasonality,the site_id a83e1a23-bef7-4772-76ff-b72a3e64726c is seasonal
# 1 for 672 seasonality,the site_id a83e1a23-bef7-4772-76ff-b72a3e64726c  Seasonality could not be identified
# 81141f05-d6e9-4ea6-36b8-0bf0509137bd ===>
# 1 for 96 seasonality,the site_id 81141f05-d6e9-4ea6-36b8-0bf0509137bd is seasonal
# 1 for 672 seasonality,the site_id 81141f05-d6e9-4ea6-36b8-0bf0509137bd  Seasonality could not be identified
# 4a169d3c-b1ec-414c-d1ea-8736507dca6e ===>
# 1 for 96 seasonality,the site_id 4a169d3c-b1ec-414c-d1ea-8736507dca6e is seasonal
# 1 for 672 seasonality,the site_id 4a169d3c-b1ec-414c-d1ea-8736507dca6e  Seasonality could not be identified
# abf118f6-6c89-5fea-b826-3fe2958cd696 ===>
# 1 for 96 seasonality,the site_id abf118f6-6c89-5fea-b826-3fe2958cd696 is seasonal
# 1 for 672 seasonality,the site_id abf118f6-6c89-5fea-b826-3fe2958cd696  Seasonality could not be identified
# 35f1db19-ab26-7f30-3451-971f053712f6 ===>
# 1 for 96 seasonality,the site_id 35f1db19-ab26-7f30-3451-971f053712f6 is seasonal
# 1 for 672 seasonality,the site_id 35f1db19-ab26-7f30-3451-971f053712f6  Seasonality could not be identified
# 012091d7-8dfd-1322-28e4-4a3c57b067c7 ===>
# 1 for 96 seasonality,the site_id 012091d7-8dfd-1322-28e4-4a3c57b067c7 is seasonal
# 2 for 672 seasonality,the site_id 012091d7-8dfd-1322-28e4-4a3c57b067c7 is seasonal
# 00374f87-909c-6ef8-847f-a7b4694ad804 ===>
# 1 for 96 seasonality,the site_id 00374f87-909c-6ef8-847f-a7b4694ad804 is seasonal
# 2 for 672 seasonality,the site_id 00374f87-909c-6ef8-847f-a7b4694ad804 is seasonal
# 5f10fb10-ef38-c5a1-10c4-7ae824cf2932 ===>
# 0 for 96 seasonality,the site_id 5f10fb10-ef38-c5a1-10c4-7ae824cf2932  Seasonality could not be identified
# 1 for 672 seasonality,the site_id 5f10fb10-ef38-c5a1-10c4-7ae824cf2932 is seasonal
# c8457bd6-c454-d94d-393e-4561f0599a06 ===>
# 1 for 96 seasonality,the site_id c8457bd6-c454-d94d-393e-4561f0599a06 is seasonal
# 2 for 672 seasonality,the site_id c8457bd6-c454-d94d-393e-4561f0599a06 is seasonal
# 7d167b7b-2871-1c6d-a474-8accad23bb94 ===>
# 1 for 96 seasonality,the site_id 7d167b7b-2871-1c6d-a474-8accad23bb94 is seasonal
# 2 for 672 seasonality,the site_id 7d167b7b-2871-1c6d-a474-8accad23bb94 is seasonal
# 9fce70d5-c75c-4954-d7b1-3a80ee099e2a ===>
# 0 for 96 seasonality,the site_id 9fce70d5-c75c-4954-d7b1-3a80ee099e2a  Seasonality could not be identified
# 0 for 672 seasonality,the site_id 9fce70d5-c75c-4954-d7b1-3a80ee099e2a  Seasonality could not be identified
# 95aecf4b-1374-11de-8c71-81a59f4714a1 ===>
# 0 for 96 seasonality,the site_id 95aecf4b-1374-11de-8c71-81a59f4714a1  Seasonality could not be identified
# 0 for 672 seasonality,the site_id 95aecf4b-1374-11de-8c71-81a59f4714a1  Seasonality could not be identified
# 134dc431-af8c-a01d-d405-64789be97420 ===>
# 1 for 96 seasonality,the site_id 134dc431-af8c-a01d-d405-64789be97420 is seasonal
# 1 for 672 seasonality,the site_id 134dc431-af8c-a01d-d405-64789be97420  Seasonality could not be identified
# f0d35789-20c5-5f6b-dd31-c75ba7f648ad ===>
# 1 for 96 seasonality,the site_id f0d35789-20c5-5f6b-dd31-c75ba7f648ad is seasonal
# 1 for 672 seasonality,the site_id f0d35789-20c5-5f6b-dd31-c75ba7f648ad  Seasonality could not be identified
# 3c1338ac-67bd-38a2-f3c2-2c362ce6b5c0 ===>
# 1 for 96 seasonality,the site_id 3c1338ac-67bd-38a2-f3c2-2c362ce6b5c0 is seasonal
# 1 for 672 seasonality,the site_id 3c1338ac-67bd-38a2-f3c2-2c362ce6b5c0  Seasonality could not be identified
# 542f6bfc-a1d2-620f-a1f1-464a7c274a69 ===>
# 1 for 96 seasonality,the site_id 542f6bfc-a1d2-620f-a1f1-464a7c274a69 is seasonal
# 1 for 672 seasonality,the site_id 542f6bfc-a1d2-620f-a1f1-464a7c274a69  Seasonality could not be identified
# a2bace58-b2d3-7df7-b5d0-f471508a6819 ===>
# 1 for 96 seasonality,the site_id a2bace58-b2d3-7df7-b5d0-f471508a6819 is seasonal
# 1 for 672 seasonality,the site_id a2bace58-b2d3-7df7-b5d0-f471508a6819  Seasonality could not be identified
# fc17f9a3-bbf8-5533-ff3e-d3697d614f92 ===>
# 0 for 96 seasonality,the site_id fc17f9a3-bbf8-5533-ff3e-d3697d614f92  Seasonality could not be identified
# 0 for 672 seasonality,the site_id fc17f9a3-bbf8-5533-ff3e-d3697d614f92  Seasonality could not be identified
# 83a41458-cc63-6fcf-aeb8-83e13b526353 ===>
# 0 for 96 seasonality,the site_id 83a41458-cc63-6fcf-aeb8-83e13b526353  Seasonality could not be identified
# 0 for 672 seasonality,the site_id 83a41458-cc63-6fcf-aeb8-83e13b526353  Seasonality could not be identified
# 38ad629b-c319-1371-b46c-ccbbda6b22d9 ===>
# 0 for 96 seasonality,the site_id 38ad629b-c319-1371-b46c-ccbbda6b22d9  Seasonality could not be identified
# 0 for 672 seasonality,the site_id 38ad629b-c319-1371-b46c-ccbbda6b22d9  Seasonality could not be identified
# 3397f38f-2dfc-97a0-eba9-770dd94c89b2 ===>
# 1 for 96 seasonality,the site_id 3397f38f-2dfc-97a0-eba9-770dd94c89b2 is seasonal
# 2 for 672 seasonality,the site_id 3397f38f-2dfc-97a0-eba9-770dd94c89b2 is seasonal
# 35d54699-97cc-50f2-6d5c-5d50607e9631 ===>
# 1 for 96 seasonality,the site_id 35d54699-97cc-50f2-6d5c-5d50607e9631 is seasonal
# 2 for 672 seasonality,the site_id 35d54699-97cc-50f2-6d5c-5d50607e9631 is seasonal
# 0ccddb37-1953-7ef2-5020-85f57887fee4 ===>
# 1 for 96 seasonality,the site_id 0ccddb37-1953-7ef2-5020-85f57887fee4 is seasonal
# 2 for 672 seasonality,the site_id 0ccddb37-1953-7ef2-5020-85f57887fee4 is seasonal
# 62956e4f-600f-ebbe-c147-be502c139aea ===>
# 1 for 96 seasonality,the site_id 62956e4f-600f-ebbe-c147-be502c139aea is seasonal
# 2 for 672 seasonality,the site_id 62956e4f-600f-ebbe-c147-be502c139aea is seasonal
# c656e88e-c6d2-d993-719f-5ee2be874dd0 ===>
# 1 for 96 seasonality,the site_id c656e88e-c6d2-d993-719f-5ee2be874dd0 is seasonal
# 1 for 672 seasonality,the site_id c656e88e-c6d2-d993-719f-5ee2be874dd0  Seasonality could not be identified
# 10f6790a-b3a4-180e-dd3f-2b3e73d5e622 ===>
# 1 for 96 seasonality,the site_id 10f6790a-b3a4-180e-dd3f-2b3e73d5e622 is seasonal
# 1 for 672 seasonality,the site_id 10f6790a-b3a4-180e-dd3f-2b3e73d5e622  Seasonality could not be identified
# 66968bd0-f5a8-f0f8-0fda-9eab6facfb65 ===>
# 1 for 96 seasonality,the site_id 66968bd0-f5a8-f0f8-0fda-9eab6facfb65 is seasonal
# 2 for 672 seasonality,the site_id 66968bd0-f5a8-f0f8-0fda-9eab6facfb65 is seasonal
# 27f88ae6-9d87-7dd1-6aa1-a67baa48a271 ===>
# 1 for 96 seasonality,the site_id 27f88ae6-9d87-7dd1-6aa1-a67baa48a271 is seasonal
# 1 for 672 seasonality,the site_id 27f88ae6-9d87-7dd1-6aa1-a67baa48a271  Seasonality could not be identified
# 3121fc1f-2063-24b7-114d-051f0e3e2cdf ===>
# 0 for 96 seasonality,the site_id 3121fc1f-2063-24b7-114d-051f0e3e2cdf  Seasonality could not be identified
# 0 for 672 seasonality,the site_id 3121fc1f-2063-24b7-114d-051f0e3e2cdf  Seasonality could not be identified
# ab2b089d-89fb-c0dc-85db-a37aea780a0e ===>
# 1 for 96 seasonality,the site_id ab2b089d-89fb-c0dc-85db-a37aea780a0e is seasonal
# 2 for 672 seasonality,the site_id ab2b089d-89fb-c0dc-85db-a37aea780a0e is seasonal
# 180634b9-3164-f1ec-b7ad-d76fede43f31 ===>
# 0 for 96 seasonality,the site_id 180634b9-3164-f1ec-b7ad-d76fede43f31  Seasonality could not be identified
# 0 for 672 seasonality,the site_id 180634b9-3164-f1ec-b7ad-d76fede43f31  Seasonality could not be identified
# 6f0a4626-425b-fa1e-60e4-ff61ac464eec ===>
# 0 for 96 seasonality,the site_id 6f0a4626-425b-fa1e-60e4-ff61ac464eec  Seasonality could not be identified
# 0 for 672 seasonality,the site_id 6f0a4626-425b-fa1e-60e4-ff61ac464eec  Seasonality could not be identified
# c388dd30-eaeb-dcfe-f76e-e2e6ebf83ce1 ===>
# 1 for 96 seasonality,the site_id c388dd30-eaeb-dcfe-f76e-e2e6ebf83ce1 is seasonal
# 2 for 672 seasonality,the site_id c388dd30-eaeb-dcfe-f76e-e2e6ebf83ce1 is seasonal
# 08ff275a-aaf6-bda6-7df1-2730c9ab29b7 ===>
# 1 for 96 seasonality,the site_id 08ff275a-aaf6-bda6-7df1-2730c9ab29b7 is seasonal
# 2 for 672 seasonality,the site_id 08ff275a-aaf6-bda6-7df1-2730c9ab29b7 is seasonal
# 275e824c-e88d-8389-18a9-21e2d0e0d0f6 ===>
# 1 for 96 seasonality,the site_id 275e824c-e88d-8389-18a9-21e2d0e0d0f6 is seasonal
# 2 for 672 seasonality,the site_id 275e824c-e88d-8389-18a9-21e2d0e0d0f6 is seasonal
# b6fd0560-0ae2-f650-2d0c-0d92e988af6e ===>
# 1 for 96 seasonality,the site_id b6fd0560-0ae2-f650-2d0c-0d92e988af6e is seasonal
# 2 for 672 seasonality,the site_id b6fd0560-0ae2-f650-2d0c-0d92e988af6e is seasonal
# 549eebeb-2468-755b-3110-c3080e17eabd ===>
# 1 for 96 seasonality,the site_id 549eebeb-2468-755b-3110-c3080e17eabd is seasonal
# 2 for 672 seasonality,the site_id 549eebeb-2468-755b-3110-c3080e17eabd is seasonal
# 1d07f991-8621-bbc8-d597-39c6b125f662 ===>
# 1 for 96 seasonality,the site_id 1d07f991-8621-bbc8-d597-39c6b125f662 is seasonal
# 2 for 672 seasonality,the site_id 1d07f991-8621-bbc8-d597-39c6b125f662 is seasonal
# 34816db2-ed2c-16d6-8416-b3849f02e9eb ===>
# 1 for 96 seasonality,the site_id 34816db2-ed2c-16d6-8416-b3849f02e9eb is seasonal
# 1 for 672 seasonality,the site_id 34816db2-ed2c-16d6-8416-b3849f02e9eb  Seasonality could not be identified
# d8db3e51-15b2-6789-eccc-0d0573239b2f ===>
# 1 for 96 seasonality,the site_id d8db3e51-15b2-6789-eccc-0d0573239b2f is seasonal
# 1 for 672 seasonality,the site_id d8db3e51-15b2-6789-eccc-0d0573239b2f  Seasonality could not be identified
# 327d1cc1-bf53-33f9-7374-184b3c7838ad ===>
# 1 for 96 seasonality,the site_id 327d1cc1-bf53-33f9-7374-184b3c7838ad is seasonal
# 1 for 672 seasonality,the site_id 327d1cc1-bf53-33f9-7374-184b3c7838ad  Seasonality could not be identified
# 811effd3-85a7-f36f-5eeb-cb38de38d5ac ===>
# 1 for 96 seasonality,the site_id 811effd3-85a7-f36f-5eeb-cb38de38d5ac is seasonal
# 1 for 672 seasonality,the site_id 811effd3-85a7-f36f-5eeb-cb38de38d5ac  Seasonality could not be identified
# e9386ab1-439f-2878-6c65-fa440370f73b ===>
# 1 for 96 seasonality,the site_id e9386ab1-439f-2878-6c65-fa440370f73b is seasonal
# 1 for 672 seasonality,the site_id e9386ab1-439f-2878-6c65-fa440370f73b  Seasonality could not be identified
# 7964ab2d-7bfa-cae3-26af-1201e192a1d0 ===>
# 1 for 96 seasonality,the site_id 7964ab2d-7bfa-cae3-26af-1201e192a1d0 is seasonal
# 1 for 672 seasonality,the site_id 7964ab2d-7bfa-cae3-26af-1201e192a1d0  Seasonality could not be identified
# dbea811b-92f8-4e35-432c-9a7d19680a6d ===>
# 1 for 96 seasonality,the site_id dbea811b-92f8-4e35-432c-9a7d19680a6d is seasonal
# 1 for 672 seasonality,the site_id dbea811b-92f8-4e35-432c-9a7d19680a6d  Seasonality could not be identified
# d4657704-6015-5cc2-1293-c4f85d4ef86e ===>
# 1 for 96 seasonality,the site_id d4657704-6015-5cc2-1293-c4f85d4ef86e is seasonal
# 1 for 672 seasonality,the site_id d4657704-6015-5cc2-1293-c4f85d4ef86e  Seasonality could not be identified
# 11ed171c-0221-da46-0fe7-67ef91fe520b ===>
# 1 for 96 seasonality,the site_id 11ed171c-0221-da46-0fe7-67ef91fe520b is seasonal
# 1 for 672 seasonality,the site_id 11ed171c-0221-da46-0fe7-67ef91fe520b  Seasonality could not be identified
# 80003fc3-a5cc-a190-a51e-1861cc7ffe03 ===>
# 1 for 96 seasonality,the site_id 80003fc3-a5cc-a190-a51e-1861cc7ffe03 is seasonal
# 1 for 672 seasonality,the site_id 80003fc3-a5cc-a190-a51e-1861cc7ffe03  Seasonality could not be identified
# 33450d85-96f7-df00-50f6-0afe4b72ab2f ===>
# 1 for 96 seasonality,the site_id 33450d85-96f7-df00-50f6-0afe4b72ab2f is seasonal
# 2 for 672 seasonality,the site_id 33450d85-96f7-df00-50f6-0afe4b72ab2f is seasonal
# 5d965a76-b72f-6dc7-165f-531184c27ea9 ===>
# 1 for 96 seasonality,the site_id 5d965a76-b72f-6dc7-165f-531184c27ea9 is seasonal
# 2 for 672 seasonality,the site_id 5d965a76-b72f-6dc7-165f-531184c27ea9 is seasonal
# ec60ce2e-5f91-5a8f-3106-90c84f9addcf ===>
# 1 for 96 seasonality,the site_id ec60ce2e-5f91-5a8f-3106-90c84f9addcf is seasonal
# 2 for 672 seasonality,the site_id ec60ce2e-5f91-5a8f-3106-90c84f9addcf is seasonal
# c29992c8-c929-3c9d-cbae-c8073f4bcc46 ===>
# 0 for 96 seasonality,the site_id c29992c8-c929-3c9d-cbae-c8073f4bcc46  Seasonality could not be identified
# 0 for 672 seasonality,the site_id c29992c8-c929-3c9d-cbae-c8073f4bcc46  Seasonality could not be identified
#                                  site_id  seasonality
# 0   67558069-06d2-2b8a-e0a8-18cc5444c287            2
# 0   de387a8e-521d-bb89-84a1-650ed26e5437            1
# 0   25b9093b-4a6a-8c35-1545-e25cee8b7f3a            1
# 0   d1668f39-1f93-e186-9d6c-acb8ba6567e4            1
# 0   d243bd72-6f64-b597-3db6-72159081dcf4            1
# ..                                   ...          ...
# 0   80003fc3-a5cc-a190-a51e-1861cc7ffe03            1
# 0   33450d85-96f7-df00-50f6-0afe4b72ab2f            2
# 0   5d965a76-b72f-6dc7-165f-531184c27ea9            2
# 0   ec60ce2e-5f91-5a8f-3106-90c84f9addcf            2
# 0   c29992c8-c929-3c9d-cbae-c8073f4bcc46            0
#
# [272 rows x 2 columns]

# %%
seasonality_check_subhourly_sampled.to_csv('fifteen_min_sampled_seasonality_check.csv')

# %%
import pickle
import numpy as np
from pandas.tseries.frequencies import to_offset
from datetime import timedelta
from scipy.fftpack import fft, fftfreq
from statsmodels.tsa.stattools import acf

file_name = "hourly_sampled.pkl"
open_file = open(file_name, "rb")
loaded_list = pickle.load(open_file)
open_file.close()

freq_data = '1H'

df_time_delta = pd.to_timedelta(to_offset(freq_data))

# Daily and Weekly seasons expected values from DF
time_lags_expected = [int(timedelta(days=1) / df_time_delta), int(timedelta(days=7) / df_time_delta)]

seasonality_check_hourly_sampled = []


for id in loaded_list:
    # get top 3 seasons
    no_of_seasons=3
    
    df1= df.loc[df['site_id']== id]
    print(id+' ===>')
    df1.interval_end = pd.to_datetime(df1.interval_end)
    df1.index= df1.interval_end
    df1.sort_index()
    df1 = df1['kw']
    
    series = np.asarray(df1)
    series_fft = fft(series)
    power = np.abs(series_fft)
    sample_freq = fftfreq(series_fft.size)
    pos_mask = np.where(sample_freq > 0)
    freqs = sample_freq[pos_mask]
    powers = power[pos_mask]
    top_powers = np.argpartition(powers, -no_of_seasons)[-no_of_seasons:]
    time_periods_from_fft = 1 / freqs[top_powers]
    time_periods = time_periods_from_fft.astype(int)
    
    count = 0
    for time_lag in time_lags_expected:
        nearest_time_lag = time_periods.flat[np.abs(time_periods - time_lag).argmin()]

        #Using 5% for range comaprison
        if nearest_time_lag in range(
                time_lag - int(0.05 * time_lag),
                time_lag + int(0.05 * time_lag)):

            # Check ACF value with lags identified from FFT.
            acf_score = acf(series, nlags=nearest_time_lag)[-1]

            # Check ACF is significant or not.
            if acf_score >= 2 / np.sqrt(len(series)):
                # ACF is significant and FFT identifies seasonality
                count = count + 1
                print(str(count)+' for '+str(time_lag)+' seasonality,the site_id '+ id+' '+'is seasonal')
        else:
            print(str(count)+' for'+' '+str(time_lag)+ ' seasonality,'+'the site_id '+ id+'  Seasonality could not be identified')
    data = pd.DataFrame({"site_id":[id],"seasonality":[count]})
    seasonality_check_hourly_sampled. append(data)

seasonality_check_hourly_sampled = pd.concat(seasonality_check_hourly_sampled)
seasonality_check_hourly_sampled
# Out:
# 5af67d8c-1379-a6e1-6014-5507848a20f7 ===>
# 0 for 24 seasonality,the site_id 5af67d8c-1379-a6e1-6014-5507848a20f7  Seasonality could not be identified
# 0 for 168 seasonality,the site_id 5af67d8c-1379-a6e1-6014-5507848a20f7  Seasonality could not be identified
# 36f7a93f-16f8-3f4d-136e-551893c0eacf ===>
# 0 for 168 seasonality,the site_id 36f7a93f-16f8-3f4d-136e-551893c0eacf  Seasonality could not be identified
# 42c0c45f-f378-fb9d-6efe-175c1b784a3a ===>
# 1 for 24 seasonality,the site_id 42c0c45f-f378-fb9d-6efe-175c1b784a3a is seasonal
# 2 for 168 seasonality,the site_id 42c0c45f-f378-fb9d-6efe-175c1b784a3a is seasonal
# 8d7108e3-ac36-ba4a-ad12-34b6ebe6664c ===>
# 1 for 24 seasonality,the site_id 8d7108e3-ac36-ba4a-ad12-34b6ebe6664c is seasonal
# 2 for 168 seasonality,the site_id 8d7108e3-ac36-ba4a-ad12-34b6ebe6664c is seasonal
# 2ae3a189-e627-5fe7-d0ac-dcbbfbab0b43 ===>
# 0 for 168 seasonality,the site_id 2ae3a189-e627-5fe7-d0ac-dcbbfbab0b43  Seasonality could not be identified
# 21e4f4d5-363b-14bd-a730-9d435d74d606 ===>
# 0 for 168 seasonality,the site_id 21e4f4d5-363b-14bd-a730-9d435d74d606  Seasonality could not be identified
# 30c1077f-52be-0374-cbd6-3cb5974a0bfd ===>
# 0 for 168 seasonality,the site_id 30c1077f-52be-0374-cbd6-3cb5974a0bfd  Seasonality could not be identified
# 3dc26230-5764-4f78-4bbe-b7fa0557b7e8 ===>
# 0 for 24 seasonality,the site_id 3dc26230-5764-4f78-4bbe-b7fa0557b7e8  Seasonality could not be identified
# 0 for 168 seasonality,the site_id 3dc26230-5764-4f78-4bbe-b7fa0557b7e8  Seasonality could not be identified
# 591c3ec2-5ab5-f4fb-318d-4f46fc4d850d ===>
# 0 for 168 seasonality,the site_id 591c3ec2-5ab5-f4fb-318d-4f46fc4d850d  Seasonality could not be identified
# aa836c84-561a-8a2a-aa0f-708f7b40ea21 ===>
# 0 for 168 seasonality,the site_id aa836c84-561a-8a2a-aa0f-708f7b40ea21  Seasonality could not be identified
# bb055294-2785-65c5-d0c3-682d88f20e03 ===>
# 0 for 168 seasonality,the site_id bb055294-2785-65c5-d0c3-682d88f20e03  Seasonality could not be identified
# 296e3ddf-41f1-ead1-2c5c-16e281dd566f ===>
# 0 for 168 seasonality,the site_id 296e3ddf-41f1-ead1-2c5c-16e281dd566f  Seasonality could not be identified
# 914a4622-8135-e1af-b78d-27324b8a2283 ===>
# 0 for 168 seasonality,the site_id 914a4622-8135-e1af-b78d-27324b8a2283  Seasonality could not be identified
# 3747c7dc-e13d-8cc1-a12b-8af1ad992d6e ===>
# 0 for 168 seasonality,the site_id 3747c7dc-e13d-8cc1-a12b-8af1ad992d6e  Seasonality could not be identified
# 39138f01-5443-f532-6462-736c6dcc10e8 ===>
# 0 for 168 seasonality,the site_id 39138f01-5443-f532-6462-736c6dcc10e8  Seasonality could not be identified
# 502d63b2-591b-5f66-2b4f-1bae154e1f4b ===>
# 0 for 168 seasonality,the site_id 502d63b2-591b-5f66-2b4f-1bae154e1f4b  Seasonality could not be identified
# 3f4c503c-b16f-6ed9-160f-acd9411489f6 ===>
# 0 for 168 seasonality,the site_id 3f4c503c-b16f-6ed9-160f-acd9411489f6  Seasonality could not be identified
# df5a0814-bc32-8b30-3014-468f18c3529e ===>
# 0 for 168 seasonality,the site_id df5a0814-bc32-8b30-3014-468f18c3529e  Seasonality could not be identified
# 61ecf3c1-f9ec-2cf1-3de7-bbe7fc425bd8 ===>
# 0 for 168 seasonality,the site_id 61ecf3c1-f9ec-2cf1-3de7-bbe7fc425bd8  Seasonality could not be identified
# 836c724d-6737-b791-d7f2-f351ca3384dc ===>
# 0 for 168 seasonality,the site_id 836c724d-6737-b791-d7f2-f351ca3384dc  Seasonality could not be identified
# 8dd2fc1b-0874-7462-b589-7ad334248d13 ===>
# 0 for 168 seasonality,the site_id 8dd2fc1b-0874-7462-b589-7ad334248d13  Seasonality could not be identified
# 1deddf70-b77f-b861-3717-95daa14c2ddd ===>
# 0 for 168 seasonality,the site_id 1deddf70-b77f-b861-3717-95daa14c2ddd  Seasonality could not be identified
# 998de051-d72a-2d40-1f2f-196f036ec8bf ===>
# 0 for 24 seasonality,the site_id 998de051-d72a-2d40-1f2f-196f036ec8bf  Seasonality could not be identified
# 0 for 168 seasonality,the site_id 998de051-d72a-2d40-1f2f-196f036ec8bf  Seasonality could not be identified
# dd0c760b-daf3-2e3d-c566-b95a0c0f2ed8 ===>
# 0 for 168 seasonality,the site_id dd0c760b-daf3-2e3d-c566-b95a0c0f2ed8  Seasonality could not be identified
# b8ec0850-c5ce-1579-5438-8d1247f0ff16 ===>
# 0 for 24 seasonality,the site_id b8ec0850-c5ce-1579-5438-8d1247f0ff16  Seasonality could not be identified
# 0 for 168 seasonality,the site_id b8ec0850-c5ce-1579-5438-8d1247f0ff16  Seasonality could not be identified
# bf42dd99-bc1a-58cf-b23a-d91e94607e4e ===>
# 0 for 24 seasonality,the site_id bf42dd99-bc1a-58cf-b23a-d91e94607e4e  Seasonality could not be identified
# 0 for 168 seasonality,the site_id bf42dd99-bc1a-58cf-b23a-d91e94607e4e  Seasonality could not be identified
# ea58e698-1408-d5c5-34fe-9fac928a4b4c ===>
# 0 for 24 seasonality,the site_id ea58e698-1408-d5c5-34fe-9fac928a4b4c  Seasonality could not be identified
# 0 for 168 seasonality,the site_id ea58e698-1408-d5c5-34fe-9fac928a4b4c  Seasonality could not be identified
# 02fb6917-572b-6e82-8f53-2dd1fb188a3c ===>
# 0 for 24 seasonality,the site_id 02fb6917-572b-6e82-8f53-2dd1fb188a3c  Seasonality could not be identified
# 0 for 168 seasonality,the site_id 02fb6917-572b-6e82-8f53-2dd1fb188a3c  Seasonality could not be identified
# 0101ee7c-a0ef-7b94-f62b-594142c8b0e6 ===>
# 0 for 24 seasonality,the site_id 0101ee7c-a0ef-7b94-f62b-594142c8b0e6  Seasonality could not be identified
# 0 for 168 seasonality,the site_id 0101ee7c-a0ef-7b94-f62b-594142c8b0e6  Seasonality could not be identified
# eccea137-1478-4434-9694-6456ee9d4674 ===>
# 0 for 24 seasonality,the site_id eccea137-1478-4434-9694-6456ee9d4674  Seasonality could not be identified
# 1 for 168 seasonality,the site_id eccea137-1478-4434-9694-6456ee9d4674 is seasonal
# d8130743-875e-d549-80d6-329656b68575 ===>
# 0 for 168 seasonality,the site_id d8130743-875e-d549-80d6-329656b68575  Seasonality could not be identified
# ea5a9c0c-6723-2114-3396-87e87ea4ae93 ===>
# 0 for 168 seasonality,the site_id ea5a9c0c-6723-2114-3396-87e87ea4ae93  Seasonality could not be identified
# 5cca460f-ace3-6061-82c9-a548171ce604 ===>
# 0 for 168 seasonality,the site_id 5cca460f-ace3-6061-82c9-a548171ce604  Seasonality could not be identified
# e7ef7c8f-7d80-c0ca-03fe-9c0f220c3d7f ===>
# 0 for 24 seasonality,the site_id e7ef7c8f-7d80-c0ca-03fe-9c0f220c3d7f  Seasonality could not be identified
# 1 for 168 seasonality,the site_id e7ef7c8f-7d80-c0ca-03fe-9c0f220c3d7f is seasonal
# 97637050-75e4-51c5-bace-70b9b45dff87 ===>
# 1 for 24 seasonality,the site_id 97637050-75e4-51c5-bace-70b9b45dff87 is seasonal
# 1 for 168 seasonality,the site_id 97637050-75e4-51c5-bace-70b9b45dff87  Seasonality could not be identified
# 628c0db4-db3e-14b8-48c8-a59cc0589a2b ===>
# 1 for 24 seasonality,the site_id 628c0db4-db3e-14b8-48c8-a59cc0589a2b is seasonal
# 1 for 168 seasonality,the site_id 628c0db4-db3e-14b8-48c8-a59cc0589a2b  Seasonality could not be identified
# b39a02a0-5140-464d-ee95-e45023c05d8d ===>
# 1 for 24 seasonality,the site_id b39a02a0-5140-464d-ee95-e45023c05d8d is seasonal
# 1 for 168 seasonality,the site_id b39a02a0-5140-464d-ee95-e45023c05d8d  Seasonality could not be identified
# 198ef94a-1013-8d08-d097-731c6d60b634 ===>
# 1 for 24 seasonality,the site_id 198ef94a-1013-8d08-d097-731c6d60b634 is seasonal
# 1 for 168 seasonality,the site_id 198ef94a-1013-8d08-d097-731c6d60b634  Seasonality could not be identified
# 7ed3c3e8-9783-acf8-e06d-be5a2366b500 ===>
# 1 for 24 seasonality,the site_id 7ed3c3e8-9783-acf8-e06d-be5a2366b500 is seasonal
# 1 for 168 seasonality,the site_id 7ed3c3e8-9783-acf8-e06d-be5a2366b500  Seasonality could not be identified
# 815bf190-4a28-b933-bac1-42f175e34117 ===>
# 1 for 24 seasonality,the site_id 815bf190-4a28-b933-bac1-42f175e34117 is seasonal
# 1 for 168 seasonality,the site_id 815bf190-4a28-b933-bac1-42f175e34117  Seasonality could not be identified
# 20c85176-6a40-9063-6043-d0831f657bd0 ===>
# 1 for 24 seasonality,the site_id 20c85176-6a40-9063-6043-d0831f657bd0 is seasonal
# 1 for 168 seasonality,the site_id 20c85176-6a40-9063-6043-d0831f657bd0  Seasonality could not be identified
# a8a44573-c3c1-c4d4-c0bb-03bb7ecddace ===>
# 1 for 24 seasonality,the site_id a8a44573-c3c1-c4d4-c0bb-03bb7ecddace is seasonal
# 1 for 168 seasonality,the site_id a8a44573-c3c1-c4d4-c0bb-03bb7ecddace  Seasonality could not be identified
# 782480db-18b5-6727-b8c6-5a492b2153f8 ===>
# 1 for 24 seasonality,the site_id 782480db-18b5-6727-b8c6-5a492b2153f8 is seasonal
# 1 for 168 seasonality,the site_id 782480db-18b5-6727-b8c6-5a492b2153f8  Seasonality could not be identified
# 44e37900-ae24-c5ec-b82c-c1ee16f051e6 ===>
# 1 for 24 seasonality,the site_id 44e37900-ae24-c5ec-b82c-c1ee16f051e6 is seasonal
# 1 for 168 seasonality,the site_id 44e37900-ae24-c5ec-b82c-c1ee16f051e6  Seasonality could not be identified
# 8bc29311-3d00-1ec4-4632-9bf8c1db339e ===>
# 1 for 24 seasonality,the site_id 8bc29311-3d00-1ec4-4632-9bf8c1db339e is seasonal
# 1 for 168 seasonality,the site_id 8bc29311-3d00-1ec4-4632-9bf8c1db339e  Seasonality could not be identified
# 318467ad-e593-a20a-fe23-daf9998cc991 ===>
# 1 for 24 seasonality,the site_id 318467ad-e593-a20a-fe23-daf9998cc991 is seasonal
# 1 for 168 seasonality,the site_id 318467ad-e593-a20a-fe23-daf9998cc991  Seasonality could not be identified
# fa1e6d9b-9562-02aa-0a4a-3f08fdf1c960 ===>
# 1 for 24 seasonality,the site_id fa1e6d9b-9562-02aa-0a4a-3f08fdf1c960 is seasonal
# 1 for 168 seasonality,the site_id fa1e6d9b-9562-02aa-0a4a-3f08fdf1c960  Seasonality could not be identified
# 92ee232b-db76-9552-baee-7a276d7beda5 ===>
# 1 for 24 seasonality,the site_id 92ee232b-db76-9552-baee-7a276d7beda5 is seasonal
# 1 for 168 seasonality,the site_id 92ee232b-db76-9552-baee-7a276d7beda5  Seasonality could not be identified
# 72429eca-0240-b236-1d1a-7f629bc2a9d9 ===>
# 1 for 24 seasonality,the site_id 72429eca-0240-b236-1d1a-7f629bc2a9d9 is seasonal
# 1 for 168 seasonality,the site_id 72429eca-0240-b236-1d1a-7f629bc2a9d9  Seasonality could not be identified
# 27834896-8120-34d1-ffea-2b9006ef3ab2 ===>
# 1 for 24 seasonality,the site_id 27834896-8120-34d1-ffea-2b9006ef3ab2 is seasonal
# 1 for 168 seasonality,the site_id 27834896-8120-34d1-ffea-2b9006ef3ab2  Seasonality could not be identified
# 09473fb0-9258-71fa-827b-fabb32404ca6 ===>
# 1 for 24 seasonality,the site_id 09473fb0-9258-71fa-827b-fabb32404ca6 is seasonal
# 1 for 168 seasonality,the site_id 09473fb0-9258-71fa-827b-fabb32404ca6  Seasonality could not be identified
# 86402464-3ce0-1d98-53ba-bf4b418d3731 ===>
# 1 for 24 seasonality,the site_id 86402464-3ce0-1d98-53ba-bf4b418d3731 is seasonal
# 1 for 168 seasonality,the site_id 86402464-3ce0-1d98-53ba-bf4b418d3731  Seasonality could not be identified
# c478ba56-575c-c594-b016-7d3061bd9b3b ===>
# 1 for 24 seasonality,the site_id c478ba56-575c-c594-b016-7d3061bd9b3b is seasonal
# 1 for 168 seasonality,the site_id c478ba56-575c-c594-b016-7d3061bd9b3b  Seasonality could not be identified
# f81d7812-364c-67ba-2379-bd4b8a6a87ba ===>
# 1 for 24 seasonality,the site_id f81d7812-364c-67ba-2379-bd4b8a6a87ba is seasonal
# 1 for 168 seasonality,the site_id f81d7812-364c-67ba-2379-bd4b8a6a87ba  Seasonality could not be identified
# ca5faf79-28d7-e07e-1c86-18ab55da408e ===>
# 1 for 24 seasonality,the site_id ca5faf79-28d7-e07e-1c86-18ab55da408e is seasonal
# 1 for 168 seasonality,the site_id ca5faf79-28d7-e07e-1c86-18ab55da408e  Seasonality could not be identified
# 8cc22eef-f6b8-8bb8-7a7d-e535f80d9a9f ===>
# 1 for 24 seasonality,the site_id 8cc22eef-f6b8-8bb8-7a7d-e535f80d9a9f is seasonal
# 1 for 168 seasonality,the site_id 8cc22eef-f6b8-8bb8-7a7d-e535f80d9a9f  Seasonality could not be identified
# eba417ce-b125-8595-6b56-11f89c2f09b8 ===>
# 1 for 24 seasonality,the site_id eba417ce-b125-8595-6b56-11f89c2f09b8 is seasonal
# 1 for 168 seasonality,the site_id eba417ce-b125-8595-6b56-11f89c2f09b8  Seasonality could not be identified
# 383e571b-d2eb-4fc0-45d8-e9dea63dec87 ===>
# 1 for 24 seasonality,the site_id 383e571b-d2eb-4fc0-45d8-e9dea63dec87 is seasonal
# 1 for 168 seasonality,the site_id 383e571b-d2eb-4fc0-45d8-e9dea63dec87  Seasonality could not be identified
# 481f0202-e3f4-47e8-ce19-b84b5114407a ===>
# 1 for 24 seasonality,the site_id 481f0202-e3f4-47e8-ce19-b84b5114407a is seasonal
# 1 for 168 seasonality,the site_id 481f0202-e3f4-47e8-ce19-b84b5114407a  Seasonality could not be identified
# 5ef5bf80-7c47-1b7a-78d8-6d8a195577f6 ===>
# 1 for 24 seasonality,the site_id 5ef5bf80-7c47-1b7a-78d8-6d8a195577f6 is seasonal
# 1 for 168 seasonality,the site_id 5ef5bf80-7c47-1b7a-78d8-6d8a195577f6  Seasonality could not be identified
# a36090f0-0dcf-7323-5919-c2fe54cb7796 ===>
# 1 for 24 seasonality,the site_id a36090f0-0dcf-7323-5919-c2fe54cb7796 is seasonal
# 1 for 168 seasonality,the site_id a36090f0-0dcf-7323-5919-c2fe54cb7796  Seasonality could not be identified
# 42767edd-b3e3-7376-0de3-78305466aa67 ===>
# 1 for 24 seasonality,the site_id 42767edd-b3e3-7376-0de3-78305466aa67 is seasonal
# 1 for 168 seasonality,the site_id 42767edd-b3e3-7376-0de3-78305466aa67  Seasonality could not be identified
# 3fdda635-72a0-16c5-900b-91e0d8cc02e0 ===>
# 1 for 24 seasonality,the site_id 3fdda635-72a0-16c5-900b-91e0d8cc02e0 is seasonal
# 1 for 168 seasonality,the site_id 3fdda635-72a0-16c5-900b-91e0d8cc02e0  Seasonality could not be identified
# 732ff022-dfcd-f47b-1062-8506a97e4b65 ===>
# 1 for 24 seasonality,the site_id 732ff022-dfcd-f47b-1062-8506a97e4b65 is seasonal
# 1 for 168 seasonality,the site_id 732ff022-dfcd-f47b-1062-8506a97e4b65  Seasonality could not be identified
# ead0f931-ace6-66a0-266d-4a1b27d96181 ===>
# 1 for 24 seasonality,the site_id ead0f931-ace6-66a0-266d-4a1b27d96181 is seasonal
# 1 for 168 seasonality,the site_id ead0f931-ace6-66a0-266d-4a1b27d96181  Seasonality could not be identified
# dc59faa0-5478-3c1a-9d24-e0c6eb7a6c4e ===>
# 1 for 24 seasonality,the site_id dc59faa0-5478-3c1a-9d24-e0c6eb7a6c4e is seasonal
# 1 for 168 seasonality,the site_id dc59faa0-5478-3c1a-9d24-e0c6eb7a6c4e  Seasonality could not be identified
# b3419bd8-785d-6ca5-3326-7219ad96c641 ===>
# 1 for 24 seasonality,the site_id b3419bd8-785d-6ca5-3326-7219ad96c641 is seasonal
# 1 for 168 seasonality,the site_id b3419bd8-785d-6ca5-3326-7219ad96c641  Seasonality could not be identified
# f642e2d0-64fb-a3a4-82a3-1e6c9374f0ae ===>
# 1 for 24 seasonality,the site_id f642e2d0-64fb-a3a4-82a3-1e6c9374f0ae is seasonal
# 1 for 168 seasonality,the site_id f642e2d0-64fb-a3a4-82a3-1e6c9374f0ae  Seasonality could not be identified
# 79ae3c7c-f1a1-90e7-c526-057e26a34eca ===>
# 1 for 24 seasonality,the site_id 79ae3c7c-f1a1-90e7-c526-057e26a34eca is seasonal
# 1 for 168 seasonality,the site_id 79ae3c7c-f1a1-90e7-c526-057e26a34eca  Seasonality could not be identified
# dcfda865-19c7-db9d-79f7-62975d5e11d5 ===>
# 1 for 24 seasonality,the site_id dcfda865-19c7-db9d-79f7-62975d5e11d5 is seasonal
# 1 for 168 seasonality,the site_id dcfda865-19c7-db9d-79f7-62975d5e11d5  Seasonality could not be identified
# 11ba23cb-dfd8-bf06-3ab1-7ac4ad6f1d5c ===>
# 1 for 24 seasonality,the site_id 11ba23cb-dfd8-bf06-3ab1-7ac4ad6f1d5c is seasonal
# 1 for 168 seasonality,the site_id 11ba23cb-dfd8-bf06-3ab1-7ac4ad6f1d5c  Seasonality could not be identified
# 20091471-e961-3d8d-0cf7-b686dff662d4 ===>
# 1 for 24 seasonality,the site_id 20091471-e961-3d8d-0cf7-b686dff662d4 is seasonal
# 1 for 168 seasonality,the site_id 20091471-e961-3d8d-0cf7-b686dff662d4  Seasonality could not be identified
# a4025fa5-e903-6079-7f04-38357974d0e0 ===>
# 1 for 24 seasonality,the site_id a4025fa5-e903-6079-7f04-38357974d0e0 is seasonal
# 2 for 168 seasonality,the site_id a4025fa5-e903-6079-7f04-38357974d0e0 is seasonal
# e4bf9a40-a95c-6488-cc12-9dfdeb781be6 ===>
# 1 for 24 seasonality,the site_id e4bf9a40-a95c-6488-cc12-9dfdeb781be6 is seasonal
# 1 for 168 seasonality,the site_id e4bf9a40-a95c-6488-cc12-9dfdeb781be6  Seasonality could not be identified
# d787f244-dfa2-59b2-d1e2-c5156e632285 ===>
# 1 for 24 seasonality,the site_id d787f244-dfa2-59b2-d1e2-c5156e632285 is seasonal
# 1 for 168 seasonality,the site_id d787f244-dfa2-59b2-d1e2-c5156e632285  Seasonality could not be identified
# b7386659-1010-f92c-4f4f-31b5b1f907c5 ===>
# 1 for 24 seasonality,the site_id b7386659-1010-f92c-4f4f-31b5b1f907c5 is seasonal
# 1 for 168 seasonality,the site_id b7386659-1010-f92c-4f4f-31b5b1f907c5  Seasonality could not be identified
# fa918bd3-d0f3-0e2d-08c6-875ade30fe3e ===>
# 1 for 24 seasonality,the site_id fa918bd3-d0f3-0e2d-08c6-875ade30fe3e is seasonal
# 2 for 168 seasonality,the site_id fa918bd3-d0f3-0e2d-08c6-875ade30fe3e is seasonal
# f2f57d71-344e-adda-6441-3b7d6620dd40 ===>
# 1 for 24 seasonality,the site_id f2f57d71-344e-adda-6441-3b7d6620dd40 is seasonal
# 1 for 168 seasonality,the site_id f2f57d71-344e-adda-6441-3b7d6620dd40  Seasonality could not be identified
# aa951f4e-7e5c-f541-9424-702ae8f31e32 ===>
# 1 for 24 seasonality,the site_id aa951f4e-7e5c-f541-9424-702ae8f31e32 is seasonal
# 1 for 168 seasonality,the site_id aa951f4e-7e5c-f541-9424-702ae8f31e32  Seasonality could not be identified
# 03dde450-8366-1cb8-1632-f6c8135b8077 ===>
# 1 for 24 seasonality,the site_id 03dde450-8366-1cb8-1632-f6c8135b8077 is seasonal
# 2 for 168 seasonality,the site_id 03dde450-8366-1cb8-1632-f6c8135b8077 is seasonal
# 35834753-fd0f-ebc7-ba6d-27c9c8de1656 ===>
# 1 for 24 seasonality,the site_id 35834753-fd0f-ebc7-ba6d-27c9c8de1656 is seasonal
# 1 for 168 seasonality,the site_id 35834753-fd0f-ebc7-ba6d-27c9c8de1656  Seasonality could not be identified
# c966b497-d639-dadc-60b5-248687103a2d ===>
# 1 for 24 seasonality,the site_id c966b497-d639-dadc-60b5-248687103a2d is seasonal
# 1 for 168 seasonality,the site_id c966b497-d639-dadc-60b5-248687103a2d  Seasonality could not be identified
# 416a448a-266c-8622-bf29-ffb262f11dba ===>
# 1 for 24 seasonality,the site_id 416a448a-266c-8622-bf29-ffb262f11dba is seasonal
# 2 for 168 seasonality,the site_id 416a448a-266c-8622-bf29-ffb262f11dba is seasonal
# d082397d-d743-fcf5-b536-762d9c7f4a35 ===>
# 0 for 24 seasonality,the site_id d082397d-d743-fcf5-b536-762d9c7f4a35  Seasonality could not be identified
# 1 for 168 seasonality,the site_id d082397d-d743-fcf5-b536-762d9c7f4a35 is seasonal
# f68751c2-aae5-2ea4-7b25-7d915b03307d ===>
# 0 for 24 seasonality,the site_id f68751c2-aae5-2ea4-7b25-7d915b03307d  Seasonality could not be identified
# 0 for 168 seasonality,the site_id f68751c2-aae5-2ea4-7b25-7d915b03307d  Seasonality could not be identified
# 549c315b-6263-d161-8762-d46d1ed5ca34 ===>
# 1 for 24 seasonality,the site_id 549c315b-6263-d161-8762-d46d1ed5ca34 is seasonal
# 2 for 168 seasonality,the site_id 549c315b-6263-d161-8762-d46d1ed5ca34 is seasonal
# b056a935-10bd-e966-af9d-ec740b88aea9 ===>
# 1 for 24 seasonality,the site_id b056a935-10bd-e966-af9d-ec740b88aea9 is seasonal
# 2 for 168 seasonality,the site_id b056a935-10bd-e966-af9d-ec740b88aea9 is seasonal
# 3bb491cc-4378-1845-cd31-41b0a3c10ad3 ===>
# 1 for 24 seasonality,the site_id 3bb491cc-4378-1845-cd31-41b0a3c10ad3 is seasonal
# 1 for 168 seasonality,the site_id 3bb491cc-4378-1845-cd31-41b0a3c10ad3  Seasonality could not be identified
# c45693f3-d18d-5c96-246d-a669bb60f3f0 ===>
# 0 for 24 seasonality,the site_id c45693f3-d18d-5c96-246d-a669bb60f3f0  Seasonality could not be identified
# 0 for 168 seasonality,the site_id c45693f3-d18d-5c96-246d-a669bb60f3f0  Seasonality could not be identified
# a1894b34-4d99-e549-e68c-8615418bcca0 ===>
# 1 for 24 seasonality,the site_id a1894b34-4d99-e549-e68c-8615418bcca0 is seasonal
# 2 for 168 seasonality,the site_id a1894b34-4d99-e549-e68c-8615418bcca0 is seasonal
# 110f08a4-548f-da24-8fd7-c6883eac9850 ===>
# 1 for 24 seasonality,the site_id 110f08a4-548f-da24-8fd7-c6883eac9850 is seasonal
# 2 for 168 seasonality,the site_id 110f08a4-548f-da24-8fd7-c6883eac9850 is seasonal
# 529d499b-a34d-324e-6c04-947e7a257a56 ===>
# 1 for 24 seasonality,the site_id 529d499b-a34d-324e-6c04-947e7a257a56 is seasonal
# 1 for 168 seasonality,the site_id 529d499b-a34d-324e-6c04-947e7a257a56  Seasonality could not be identified
# 1c5547b1-7182-ad18-991b-0e6663379849 ===>
# 1 for 24 seasonality,the site_id 1c5547b1-7182-ad18-991b-0e6663379849 is seasonal
# 2 for 168 seasonality,the site_id 1c5547b1-7182-ad18-991b-0e6663379849 is seasonal
# 72f8bc16-6c01-b9f1-b89d-8c38c11f0046 ===>
# 1 for 24 seasonality,the site_id 72f8bc16-6c01-b9f1-b89d-8c38c11f0046 is seasonal
# 1 for 168 seasonality,the site_id 72f8bc16-6c01-b9f1-b89d-8c38c11f0046  Seasonality could not be identified
#                                  site_id  seasonality
# 0   5af67d8c-1379-a6e1-6014-5507848a20f7            0
# 0   36f7a93f-16f8-3f4d-136e-551893c0eacf            0
# 0   42c0c45f-f378-fb9d-6efe-175c1b784a3a            2
# 0   8d7108e3-ac36-ba4a-ad12-34b6ebe6664c            2
# 0   2ae3a189-e627-5fe7-d0ac-dcbbfbab0b43            0
# ..                                   ...          ...
# 0   a1894b34-4d99-e549-e68c-8615418bcca0            2
# 0   110f08a4-548f-da24-8fd7-c6883eac9850            2
# 0   529d499b-a34d-324e-6c04-947e7a257a56            1
# 0   1c5547b1-7182-ad18-991b-0e6663379849            2
# 0   72f8bc16-6c01-b9f1-b89d-8c38c11f0046            1
#
# [94 rows x 2 columns]

# %%
seasonality_check_hourly_sampled.to_csv('hourly_siteid_seasonality_result.csv')

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4g}'.format
import enlopy as el
from sklearn.preprocessing import MaxAbsScaler
import pickle

def findFirstAndLast(arr, n, x) :
    first = -1
    last = -1
    for i in range(0, n) :
        if (x != arr[i]) :
            continue
        if (first == -1) :
            first = i
        last = i
    return [first, last+1];

file_name = "hourly_sampled.pkl"
open_file = open(file_name, "rb")
loaded_list = pickle.load(open_file)
open_file.close()

hourly_site_id_seasonality = pd.read_csv('hourly_siteid_seasonality_result.csv')
hourly_site_id_seasonality = hourly_site_id_seasonality[['site_id','seasonality']]


load_curve_of_hourly_seasonal_sites = []
daily_startup_shutdown_hourly_seasonal_sites = []


for i in range(0,len(loaded_list)):
    df1= df.loc[df['site_id']== loaded_list[i]]
    df2 = hourly_site_id_seasonality.loc[hourly_site_id_seasonality['site_id']==loaded_list[i]]
    print(loaded_list[i]+' ===>')
    df1.interval_end = pd.to_datetime(df1.interval_end)
    df1.index= df1.interval_end
    df1.sort_index()
    df1 = df1['kw']
    if int(df2.seasonality.values)> 0:
        load_series = el.make_timeseries(x = df1.values,  year = pd.to_datetime(df1.index[0]).year, 
                            startdate = pd.to_datetime(df1.index[0]), freq='1H') 
        try:
            load_curve  = el.analysis.get_load_archetypes(load_series, k=1, x='hour', y='dayofyear', plot_diagnostics=False)
            transformer = MaxAbsScaler().fit(load_curve)
            transformed_load_curve = transformer.transform(load_curve)
            load_curve  = load_curve.flatten()
            transformed_load_curve = transformed_load_curve.flatten()

            max_load = max(load_curve)
            on_off = []
            for j in range(0, len(transformed_load_curve)):
                if transformed_load_curve[j]>= 0.8* max_load:
                    on_off.append(1)
                else:
                    on_off.append(0)

            list_of_times = findFirstAndLast(on_off, len(on_off), 1)

            dataframe_loadcurve = pd.DataFrame({"site_id": [loaded_list[i]],"load_curve":[load_curve]}) 
            load_curve_of_hourly_seasonal_sites.append(dataframe_loadcurve)
            dataframe_of_times = pd.DataFrame({"site_id": [loaded_list[i]],"times_of_operation":[list_of_times]}) 
            daily_startup_shutdown_hourly_seasonal_sites.append(dataframe_of_times)
        
        except ValueError:
            pass

load_curve_of_hourly_seasonal_sites = pd.concat(load_curve_of_hourly_seasonal_sites)
daily_startup_shutdown_hourly_seasonal_sites = pd.concat(daily_startup_shutdown_hourly_seasonal_sites)
# Out:
# 5af67d8c-1379-a6e1-6014-5507848a20f7 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 36f7a93f-16f8-3f4d-136e-551893c0eacf ===>
# 42c0c45f-f378-fb9d-6efe-175c1b784a3a ===>
# 8d7108e3-ac36-ba4a-ad12-34b6ebe6664c ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 2ae3a189-e627-5fe7-d0ac-dcbbfbab0b43 ===>
# 21e4f4d5-363b-14bd-a730-9d435d74d606 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 30c1077f-52be-0374-cbd6-3cb5974a0bfd ===>
# 3dc26230-5764-4f78-4bbe-b7fa0557b7e8 ===>
# 591c3ec2-5ab5-f4fb-318d-4f46fc4d850d ===>
# aa836c84-561a-8a2a-aa0f-708f7b40ea21 ===>
# bb055294-2785-65c5-d0c3-682d88f20e03 ===>
# 296e3ddf-41f1-ead1-2c5c-16e281dd566f ===>
# 914a4622-8135-e1af-b78d-27324b8a2283 ===>
# 3747c7dc-e13d-8cc1-a12b-8af1ad992d6e ===>
# 39138f01-5443-f532-6462-736c6dcc10e8 ===>
# 502d63b2-591b-5f66-2b4f-1bae154e1f4b ===>
# 3f4c503c-b16f-6ed9-160f-acd9411489f6 ===>
# df5a0814-bc32-8b30-3014-468f18c3529e ===>
# 61ecf3c1-f9ec-2cf1-3de7-bbe7fc425bd8 ===>
# 836c724d-6737-b791-d7f2-f351ca3384dc ===>
# 8dd2fc1b-0874-7462-b589-7ad334248d13 ===>
# 1deddf70-b77f-b861-3717-95daa14c2ddd ===>
# 998de051-d72a-2d40-1f2f-196f036ec8bf ===>
# dd0c760b-daf3-2e3d-c566-b95a0c0f2ed8 ===>
# b8ec0850-c5ce-1579-5438-8d1247f0ff16 ===>
# bf42dd99-bc1a-58cf-b23a-d91e94607e4e ===>
# ea58e698-1408-d5c5-34fe-9fac928a4b4c ===>
# 02fb6917-572b-6e82-8f53-2dd1fb188a3c ===>
# 0101ee7c-a0ef-7b94-f62b-594142c8b0e6 ===>
# eccea137-1478-4434-9694-6456ee9d4674 ===>
# d8130743-875e-d549-80d6-329656b68575 ===>
# ea5a9c0c-6723-2114-3396-87e87ea4ae93 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 5cca460f-ace3-6061-82c9-a548171ce604 ===>
# e7ef7c8f-7d80-c0ca-03fe-9c0f220c3d7f ===>
# 97637050-75e4-51c5-bace-70b9b45dff87 ===>
# 628c0db4-db3e-14b8-48c8-a59cc0589a2b ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# b39a02a0-5140-464d-ee95-e45023c05d8d ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 198ef94a-1013-8d08-d097-731c6d60b634 ===>
# 7ed3c3e8-9783-acf8-e06d-be5a2366b500 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 815bf190-4a28-b933-bac1-42f175e34117 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 20c85176-6a40-9063-6043-d0831f657bd0 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# a8a44573-c3c1-c4d4-c0bb-03bb7ecddace ===>
# 782480db-18b5-6727-b8c6-5a492b2153f8 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 44e37900-ae24-c5ec-b82c-c1ee16f051e6 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 8bc29311-3d00-1ec4-4632-9bf8c1db339e ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 318467ad-e593-a20a-fe23-daf9998cc991 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# fa1e6d9b-9562-02aa-0a4a-3f08fdf1c960 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 92ee232b-db76-9552-baee-7a276d7beda5 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 72429eca-0240-b236-1d1a-7f629bc2a9d9 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 27834896-8120-34d1-ffea-2b9006ef3ab2 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 09473fb0-9258-71fa-827b-fabb32404ca6 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 86402464-3ce0-1d98-53ba-bf4b418d3731 ===>
# c478ba56-575c-c594-b016-7d3061bd9b3b ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# f81d7812-364c-67ba-2379-bd4b8a6a87ba ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# ca5faf79-28d7-e07e-1c86-18ab55da408e ===>
# 8cc22eef-f6b8-8bb8-7a7d-e535f80d9a9f ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# eba417ce-b125-8595-6b56-11f89c2f09b8 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 383e571b-d2eb-4fc0-45d8-e9dea63dec87 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 481f0202-e3f4-47e8-ce19-b84b5114407a ===>
# 5ef5bf80-7c47-1b7a-78d8-6d8a195577f6 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# a36090f0-0dcf-7323-5919-c2fe54cb7796 ===>
# 42767edd-b3e3-7376-0de3-78305466aa67 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 3fdda635-72a0-16c5-900b-91e0d8cc02e0 ===>
# 732ff022-dfcd-f47b-1062-8506a97e4b65 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# ead0f931-ace6-66a0-266d-4a1b27d96181 ===>
# dc59faa0-5478-3c1a-9d24-e0c6eb7a6c4e ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# b3419bd8-785d-6ca5-3326-7219ad96c641 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# f642e2d0-64fb-a3a4-82a3-1e6c9374f0ae ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 79ae3c7c-f1a1-90e7-c526-057e26a34eca ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# dcfda865-19c7-db9d-79f7-62975d5e11d5 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 11ba23cb-dfd8-bf06-3ab1-7ac4ad6f1d5c ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 20091471-e961-3d8d-0cf7-b686dff662d4 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# a4025fa5-e903-6079-7f04-38357974d0e0 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# e4bf9a40-a95c-6488-cc12-9dfdeb781be6 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# d787f244-dfa2-59b2-d1e2-c5156e632285 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# b7386659-1010-f92c-4f4f-31b5b1f907c5 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# fa918bd3-d0f3-0e2d-08c6-875ade30fe3e ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# f2f57d71-344e-adda-6441-3b7d6620dd40 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# aa951f4e-7e5c-f541-9424-702ae8f31e32 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 03dde450-8366-1cb8-1632-f6c8135b8077 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 35834753-fd0f-ebc7-ba6d-27c9c8de1656 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# c966b497-d639-dadc-60b5-248687103a2d ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 416a448a-266c-8622-bf29-ffb262f11dba ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# d082397d-d743-fcf5-b536-762d9c7f4a35 ===>
# f68751c2-aae5-2ea4-7b25-7d915b03307d ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 549c315b-6263-d161-8762-d46d1ed5ca34 ===>
# b056a935-10bd-e966-af9d-ec740b88aea9 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 3bb491cc-4378-1845-cd31-41b0a3c10ad3 ===>
# c45693f3-d18d-5c96-246d-a669bb60f3f0 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# a1894b34-4d99-e549-e68c-8615418bcca0 ===>
# 110f08a4-548f-da24-8fd7-c6883eac9850 ===>
# 529d499b-a34d-324e-6c04-947e7a257a56 ===>
# 1c5547b1-7182-ad18-991b-0e6663379849 ===>
# /Users/abulhasanfahad/opt/anaconda3/envs/ml/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 72f8bc16-6c01-b9f1-b89d-8c38c11f0046 ===>

# %%
load_curve_of_hourly_seasonal_sites.to_csv('hourly_meters_load_curve.csv')
